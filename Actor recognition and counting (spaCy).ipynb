# %% [markdown]
# # Coding actors
#
# Actors are counted using NER. Two categories are then used: PERSON and ORGANIZATION.
#
# The process has three steps:
# 1. Summarising the unique actors and listing these in a separate data file
# 2. Coding them (See separate notebook `Coding actors.ipynb`)
# 3. Counting them automatically
#
# #### Category selection
# The choice is made to select only PERSON and ORGANIZATION for coding. The CoreNLP NER is good enough to separate these. If they are confused, they often seem to fit in each other's categories. The MISC category catches whatever is left that is obviously not a date, number, ordinal or location. If there are false negatives, they should be there. The category, however, is fairly large. Therefore, for initial coding the PERSON and ORGANIZATION tags should suffice.
#
# #### Counting
# Counting is rather tedious in this case, because names of actors might overlap and therefore lead to double counting. Consider the following few options. These strings overlap in multiple situation. Firstly, all overlap with 'Council', leading to double counting. Secondly, 'Council of Ministers' overlaps with 'Council of Ministers Committee of Permanent Representatives', leading to triple counting.
#
# ```
# Council
# Council Presidency
# Council of 16
# Council of Europe
# Council of General Affairs
# Council of Ministers
# Council of Ministers Committee of Permanent Representatives
# Council of the European Union
# Council of the Union
# ```
#
# This is overcome using `re.findall()`, which finds all non-overlapping matches. The regular expression is built up using or statements (e.g. `'Council Presidency|Council'`), where regex **takes only the first match** from the pattern if they overlap. Therefore, to find the unique matches, ignoring overlapping substrings, the different entities have to be sorted by length before bulding the pattern. To clarify, consider the following:
#
# ```Python
# sentence = 'This sentence is about the Council Presidency'
# print(re.findall('Council Presidency|Council',sentence))
# # ['Council Presidency']
# print(re.findall('Council|Council Presidency',sentence))
# # ['Council']
# ```
#
# The former is correct, hence the sorting. The pattern is precompiled in order to save computation time.

# %%
import pandas as pd
import json
from ner_methods import *
import spacy
import re
import codingtools

corenlp_ram = '2g'
settings_file = 'D:/thesis/settings.json'

# %%
#Preparation

#Read settings
settings = json.loads(open(settings_file).read())["settings"]

#Read data
df = pd.read_csv(settings['data_csv'])

# %%
#Unique named entities
uniqueEntities = set()

counter = 0
errorList = []

nlp = spacy.load('en_core_web_sm')
for text in df['TEXT']:
    try: #Sometimes texts give errors, e.g. when different alphabets are used. Therefore list those.
        uniqueEntities.update(getUniqueEntities(text,nlp))
    except:
        errorList.append(str(counter))
    counter += 1

print("Errors occurred on indices:",", ".join(errorList))

##Sort entities into categories
entity_map = {}

for (entity,entity_type) in uniqueEntities:
    if entity_type not in entity_map: #Set element to the correct data format to then add elements
        entity_map[entity_type] = set()
        
    entity_map[entity_type].add(entity)
    
print("Entities were found in the following categories:",", ".join(entity_map.keys()))

##Save output of uncoded actors to CSV, sorted alphabetically
with open(settings['person_csv'],'w+',encoding = 'utf-8') as f:
    for person in sorted(entity_map['PERSON']):
        f.write(person+'\n')

with open(settings['org_csv'],'w+',encoding = 'utf-8') as f:
    for org in sorted(entity_map['ORG']):
        f.write(org+'\n')
# Out:
# Errors occurred on indices:
# Entities were found in the following categories: DATE, CARDINAL, ORG, GPE, NORP, PERSON, LOC, EVENT, PERCENT, MONEY, WORK_OF_ART, FAC, LAW, PRODUCT, ORDINAL, TIME, QUANTITY, LANGUAGE

# %%
# Counting actors

# Assuming coding is done using the extension from codingtools, this initiates a copy of that instance of codingTool
with open(settings['codes'], 'r', encoding = 'utf-8') as f:
    coding = codingtools.from_json(f.read())
codes = coding.coded
categories = coding.categories

#As mentioned above, keys should be sorted by length for correct matching of overlapping cases
keys = sorted(list(codes.keys()), key = len, reverse = True)
keys_pattern = re.compile('|'.join(keys))

df['ACTORS'] = df['TEXT'].map(lambda x: set(re.findall(keys_pattern,x)))

for category in categories:
    df['count_'+category] = df['ACTORS'].map(lambda x: len([1 for element in x if (codes[element] == category)]))

# %%
#Output to csv
df.to_csv(settings['data_csv'])

# %%
entity_map['ORG']
# Out:
# {' Brussels: Council of the European Union',
#  ' The European Commission',
#  '"Partnership for Europe',
#  '0 Department for Exiting the European Union Policy on Businesses',
#  '1 Dyson Department',
#  '1 Foods Department for Exiting the European Union Policy on Foods',
#  '2B EN Council',
#  '3 Krall Department for Exiting the European Union',
#  '4 Department for Exiting the European Union',
#  '4 Department for Exiting the European Union Policy on Businesses',
#  '6-month EU Council',
#  '6/15 PV\\1138471EN.docx EN Results',
#  '7 Group Department for Exiting the European Union Policy on Life Sciences',
#  '8 Creative Industries Department for Exiting Federation the European Union Policy on Creative',
#  '8 Group Department',
#  'AB Discussion',
#  'AB Foods Discussion on Department for Exiting the European Union Policy on Foods',
#  'ACER Administrative Board',
#  'ACP',
#  'ADD 1 Compilation of Comments of the Draft Conduct of the Call for Contribution',
#  'ADD 1 Draft Framework',
#  'ADD 1 UD',
#  'ADDED',
#  'AFCO',
#  'AFET',
#  'AGRI',
#  'AIS Corporation',
#  'ALDE',
#  'ALDE Fredrick Federley',
#  'AM - PE608.017v01-00',
#  'ARC Digitized Raster Graphics',
#  'AS',
#  'ASEAN',
#  'AT&T',
#  'Advanced Military Training',
#  'African National Congress',
#  'Agriculture Councils',
#  'Ahtisaari',
#  'Aizstajeji/Pavaduojantysnariai/Póttagok/Sostituti/Plaatsvervangers/Zas',
#  'Allister Heath',
#  'Amnesty International',
#  'Andere Teilnehmer/Muud',
#  'Anelay 6 Executive',
#  "Angola's Government of Unity and National Reconciliation",
#  'Asistent/Assistent/Assistenz/Bοηθός/Assistant/Assistente',
#  'Asistent/Assistent/Assistenz/Bοηθός/Assistant/Assistente/Pal īgs/Padėjėjas',
#  'Assembly',
#  'Association of Chief Executives Discussion on Department for Exiting the European Union',
#  'Association of Department for',
#  'Association of Medical Discussion on 9 Research Charities Department for Exiting the European Union Policy',
#  'Association of Medical Research Charities Discussion on Department for Exiting the European Union Policy Lord Callanan 2017-12-04 Graham Farrant',
#  'Association of Southeast Asian Nations',
#  'Asszisztens/Asystent/',
#  'Asszisztens/Asystent/Pomocnik/ Avustaja/',
#  'Austrian Press and Information Service',
#  'Austrian Representative Office',
#  'Ayala Sender',
#  'BBC',
#  'BBC Media',
#  'BBC REPORT',
#  'BH Press',
#  'Bagby',
#  'Bank',
#  'Boeing Department for Exiting',
#  'Boeing Discussion on Department for Exiting the European Union Policy on Aerospace Robin Walker',
#  'Brigitte Bardot',
#  'British Medical Association Discussion on Department',
#  'British Medical Discussion on 8 Association Department for',
#  'British Telecom',
#  'British Telecommunications P.L.C.',
#  'Business Discussion',
#  'Business Representative Department',
#  'Business Representative Organisations Discussion on Department',
#  'CADRG',
#  'CDIP',
#  'CEI',
#  'CFSP',
#  'CIA-01',
#  'CIS',
#  'COUNCIL',
#  'COUNCIL OF MINISTERS',
#  'COUNTRIES JOINED',
#  'CSDP Military Training"',
#  'CSDP Missions',
#  'CSDP Operations',
#  'CSDP WK',
#  'CULT',
#  'CURRENT',
#  'Cabinet',
#  'Central',
#  'Central and Eastern Europe',
#  'Chair',
#  'Chamber of Commerce Dinner Department',
#  'Chef',
#  'Chief Executive',
#  'Christopher Bellamy Department',
#  'Ciampi Report',
#  'Citas',
#  'Cognac',
#  'Combined Authority Mayors Department',
#  'Combined Authority Mayors Discussion on Department for Exiting the European Union',
#  'Commissiesecretariaat/Sekretariat komisji/',
#  'Commission',
#  'Committee on Industry, Research and Energy',
#  'Common Foreign and Security Policy',
#  'Common Position',
#  'Community',
#  'Congress',
#  'Consumer Credit Directive',
#  'Consumer groups Discussion on Department for Exiting the European Union Policy on Consumers Robin Walker',
#  'Convention',
#  'Council',
#  'Council of Ministers',
#  'Council of the European Union',
#  'Court',
#  'Court of First Instance',
#  'Cowell',
#  'Creative Industries Federation Discussion on Department for Exiting the European Union Policy on Creative',
#  'Customs Union',
#  'Cyprus',
#  'Cyprus (AP',
#  'DATA',
#  'DCLG / EU Exit Roundtable',
#  'DCLG / EU Exit Roundtable, Discussion on 0',
#  'DE',
#  'DEFENSE',
#  'DG',
#  'DG G 3 B EN Council',
#  'DG GROW',
#  'DGC',
#  'DRAFT European Union',
#  'DT - PE605.981v02-00 Opinions',
#  'Dail',
#  'Danes',
#  'Danner',
#  'Deane',
#  'Defense',
#  'Defense Committee',
#  'Definitions Revision',
#  'Dennis Radtke',
#  'Department for Exiting',
#  'Department for Exiting Consumer',
#  'Department for Exiting the European Union',
#  'Department for Exiting the European Union Policy Baroness 2017-10-1 United Kingdom Discussion on Anelay 0',
#  'Department for Exiting the European Union Policy Baroness Anelay',
#  'Department for Exiting the European Union Policy Lord',
#  'Department for Exiting the European Union Policy Lord Callanan 2017-12-1',
#  'Department for Exiting the European Union Policy Robin Walker 2017-10-0 Professional Business Discussion on 5 Services Council Department for Exiting the European Union Policy on Businesses',
#  'Department for Exiting the European Union Policy on Automotive',
#  'Department for Exiting the European Union Policy on Businesses',
#  'Deputaţi/',
#  'Deputāts/Narys/',
#  'Didier Guennoc',
#  'Digital River',
#  'Dijon',
#  'Direcção-Geral/Directii Generale',
#  'Direcção-Geral/Direcţii Generale',
#  'Direttorat Ġenerali/Directoraten',
#  'Discussion on 1 Representatives',
#  'Discussion on 2 Representatives from',
#  'Discussion on 4 Representatives',
#  'Discussion on 6 Representatives',
#  'Discussion on 7 Representatives',
#  'Discussion on 7 Representatives from Department for Exiting Higher Education',
#  'Discussion on 7 Representatives from Small Department for Exiting',
#  'Discussion on 8 Representatives',
#  'Discussion on 9 Representatives',
#  'Discussion on Department for Exiting the European Union',
#  'Discussion on Department for Exiting the European Union Policy',
#  'Discussion on Department for Exiting the European Union Policy Baroness Anelay',
#  'Discussion on Department for Exiting the European Union Policy Robin Walker',
#  'Discussion on Department for Exiting the European Union Policy on Businesses',
#  'Discussion on Department for Exiting the European Union Policy on Professional and Business Services',
#  'Draft Military Advice',
#  'Dubrovnik',
#  'Dyson Discussion on Department for Exiting the European Union Policy on Businesses',
#  'EC',
#  'ECGI',
#  'ECON',
#  'ECONOMY Sweden',
#  'ECU(A',
#  'EEAS Food for Thought Paper',
#  'EEAS Food for Thought Paper:',
#  'EEAS Food for Thought Paper: Permanent Structured Cooperation (PESCO)',
#  'EEAS Food for Thought Paper: Permanent Structured Cooperation (PESCO) 20/02/2017 WK',
#  'EEAS/Commission',
#  'EGG',
#  'ELARG 43 Interinstitutional File',
#  'EMU',
#  'EN',
#  'EN 8 2 Agreement',
#  'EN Asset Management',
#  'EN Council',
#  'EN European Parliament',
#  'EN Rapporteur',
#  'EN Results',
#  'EN WK',
#  'EN WK 1591',
#  'EN Наблдатели/Observadores/Pozorovatelé/Observatører/Beobachter/Vaatlejad/Παρατηρητ ές/Observers/',
#  'EN ПРИСЪСТВЕН',
#  'EN Секретариат',
#  'ENF',
#  'ENF Angelo Ciocca',
#  'EP',
#  'EU',
#  'EU Battlegroups',
#  'EU CCS',
#  'EU CSDP Military Operations',
#  'EU Commission',
#  'EU Common Security Defence Policy Military Operations',
#  'EU Concept',
#  'EU Constitutional Treaty',
#  'EU Council',
#  'EU Council of Ministers',
#  'EU Crisis Management',
#  'EU Life Sciences Steering Discussion',
#  'EU Life Sciences Steering Group Discussion on Department',
#  'EU Life Sciences Steering Group Discussion on Department for Exiting the European Union Policy on Life Sciences',
#  'EU Military Concept for Personnel Recovery REV 1 WK',
#  'EU Military Concept for Personnel Recovery REV 1 WK 11112 2017',
#  'EU Military Conceptual',
#  'EU Military Conceptual Development',
#  'EU Military Conceptual Development 13/02/2017 WK',
#  'EU Military Training and Education Annual Report 2016',
#  'EU Operations',
#  'EU Policy on Training',
#  'EU Policy on Training for',
#  'EU Policy on Training for CSDP 01/02/2017',
#  'EU Training Mission Plans',
#  'EU) Council of General Affairs',
#  'EUMC Draft Military Advice',
#  'EUMS',
#  'EUMS Director Communication and Information Systems',
#  'EUROFOUND Agency',
#  'EUROPEAN UNION',
#  'EUROPEAN UNION LEGISLATION',
#  'EUROSTAT',
#  'EVCA',
#  'EXAMPLE',
#  'Eastern',
#  'Economic and Monetary Union',
#  'Education',
#  'Education Sector Discussion on Department for Exiting the European Union Policy on Higher Education',
#  'Embassy',
#  'Energy UK Department for',
#  'Energy UK Discussion on Department for Exiting the European Union Policy on Energy Robin Walker',
#  'Erwin',
#  'Essen European Council',
#  'European Commission',
#  'European Council',
#  'European Council Decision 2011/199/EU',
#  'European Council Decisions',
#  'European Discussion',
#  'European Parliament',
#  'European Union',
#  'European Union Military Committee European Union Military Committee Working Group European Union Military Committee Working Group',
#  'European Union Military Committee Working Group',
#  'European Union Sanctions',
#  'European Union Trade',
#  "European Union's",
#  'European Unions',
#  'Eurotunnel Discussion on Department',
#  'Ex-Yugoslavia',
#  'Exchange of Letters',
#  'Exiting Federation the European Union Policy on Food and Drink Robin Walker',
#  'Exiting Organisations the European Union Policy on Businesses',
#  'Exiting Registrar, Association of the European Union',
#  'Exiting the European Union',
#  'Exiting the European Union Policy',
#  'Exiting the European Union Policy on Businesses',
#  'Export Development Bank of Iran',
#  'External Economic Relations',
#  'External Relations -- Economic and Financial Affairs',
#  'F.W. De Klerk',
#  'FEMM',
#  'FER',
#  'FINS DG',
#  'FORTH',
#  'FSA',
#  'FURTHER NATIONS',
#  'Federation',
#  'Figueira (European Commission',
#  'Finance',
#  'Financial Services Authority',
#  'Fischer',
#  'Food and Drinks Federation Discussion on Department for Exiting the European Union Policy on Food and Drink Robin Walker 2017-',
#  'Food for Thought Paper',
#  'Foreign',
#  'Foreign Affairs',
#  'Foreign Affairs Council',
#  'Foreign Ministry',
#  "Fortune Asset Management's",
#  'Franz Weber Foundation',
#  'Freund',
#  'Functionar/Úradník',
#  'G5',
#  'GAAP',
#  'GAM',
#  'GATT',
#  'GUE',
#  'General Affairs',
#  'General Affairs Council',
#  'Generali/Directoraten',
#  'Generally Accepted Accounting Principles',
#  'Geral/Cabinet Secretar General/Kancelária',
#  'German Tornado',
#  "Giscard d'Estaing",
#  'Goeteborg University',
#  'Gooch',
#  'Gordon Discussion',
#  'Government',
#  'Government of National Unity',
#  'Gradin',
#  'Great Yarmouth Department',
#  'Great Yarmouth Discussion on Department',
#  'Greece European Union',
#  'Greek Cypriots',
#  'Greek-',
#  'Green Party',
#  'Grup Politycznych/Secr',
#  'Guardian',
#  'Gunther Marten',
#  'H.E.',
#  'HOLLAND',
#  'HOME COUNTRY',
#  'HOST',
#  'Helsinki',
#  'Higher Education Discussion on Department',
#  'Home Affairs',
#  'Home Affairs Council',
#  'Home Office',
#  'Hughes',
#  'IAS',
#  'IGC',
#  'ILO',
#  'ILOG',
#  'ILOG Inc.',
#  'ILOG Professional Services',
#  'ILOG S.A.',
#  'INIT 04/10/2017',
#  'INIT 06/10/2017',
#  'INIT 13/12/2017 Draft',
#  'INIT 17/11/2017 Draft Military Advice',
#  'INIT 23/11/2017 Draft Information',
#  'INIT MILITARY INPUT',
#  'INSTRUMENTS Subject',
#  'INTER',
#  'IPOL',
#  'ITAR',
#  'ITEC DG',
#  'ITRE',
#  'ITRE Co-Chair',
#  'ITRE IMCO -',
#  'ITRE Opinions',
#  'Ierednis/Pareigunas/Tisztviselo/Ufficjal/Ambtenaar/Urzednik',
#  'Industry and Research',
#  'Integrated Coordination Hub',
#  'Inter-governmental',
#  'Intergovernmental Conference on Institutional Reform',
#  'Irish Justice Department',
#  'Irish Livestock Committee',
#  'Ivana Damjanic-Bresan',
#  'Izetbegovic',
#  'JCB Discussion',
#  'JCB Discussion on Department for Exiting',
#  'JCB Suppliers Round',
#  'JELENLÉTI',
#  'Joint EMPL/ITRE',
#  'Juridische Dienst/',
#  'Jurídico/Právní',
#  'Jurídico/Právní služba/Juridisk Tjeneste/Juristischer Dienst/Õigusteenistus/Νομική',
#  'Justice',
#  'Justus Lipsius',
#  'Katsav',
#  'Kigali',
#  'Kinshasa',
#  'Kitos institucijos/',
#  'Kitos institucijos/ Más',
#  'Knesset',
#  'Komise/Kommissionen/Kommission/Euroopa Komisjon',
#  'Komisija/Commissione/Bizottság/ Kummissjoni/Commissie/Komisja/Comissão/Comisie',
#  'Komisja/Comissão/Comisie',
#  'Komissio/Kommissionen',
#  'Koмисия/Comisión/Komise/Kommissionen/Kommission/Euroopa Komisjon/Eπιτροπή/Commission/Komisija/Commissione/Bizottság/ Kummissjoni/Commissie/',
#  'Kremlin',
#  'Kurdish Workers Party',
#  'LARGER NATIONS',
#  'LENGTH',
#  'LIBE',
#  'LISTINA/SEZNAM',
#  'LISTINA/SEZNAM NAVZOCIH/LÄSNÄOLOLISTA/DELTAGARLISTA Брo/Mesa/Predsednictvo/Formandskabet/Vorstand/Juhatus/Προεδρείο/Bureau/',
#  'LL',
#  'LONG DORMANT DEFENSE ORGANIZATION',
#  'LUXEMBOURG Brushing',
#  'Land Department',
#  'Legal Challenges',
#  'Legal Scenarios',
#  'Leonardo Department',
#  'Leonardo Discussion on Department for Exiting the European Union Policy on Businesses',
#  'Lid/Czlonek/Membro/Membru/Clen/Poslanec/Jäsen/Ledamot (F',
#  'Lithuanian Business',
#  'Luxembourg Business Roundtable Discussion on Department',
#  'MAJOR',
#  'MANAGEMENT OPERATIONS',
#  'MBDA Missile Systems Discussion',
#  'MBDA Missile Systems Discussion on Department',
#  'MFF',
#  'Macedonian',
#  'Maňka',
#  'Maria-Elena Cowell',
#  'Maryam Jamshidi',
#  'Mate Granic',
#  'Matesa',
#  'Mayor, Tees Discussion on 6 Valley Combined Authority Department for Exiting the European Union',
#  'Mayotte',
#  'McCarty',
#  'McClure',
#  'Media Engagement',
#  'Media Engagement 0',
#  'Media Engagement 1',
#  'Media Engagement 2',
#  'Membri/Leden/Posłowie/Depu',
#  'Mercosur',
#  'Mesic',
#  'Mickey Kantor',
#  'Miroslav Poche',
#  'Missions - Compilation of Comments 15/03/2017 WK 521',
#  'Missions 21/03/2017',
#  'Moratinos',
#  "Mostar the ''",
#  'Mostar.',
#  'Muckross Abbey',
#  'Muut',
#  'NAIROBI',
#  'NATO',
#  'NAZOCNIH/ELENCO DI',
#  'NEW',
#  'NEW LEGAL',
#  'NGL Sakorafa Sofia',
#  'NLD',
#  'NLE',
#  'NM France',
#  'NON',
#  'NOTE Subject',
#  'NPR',
#  "NPR's Office of the General Counsel",
#  'National Assembly',
#  'National League for Democracy',
#  'National Press Club Newsmaker Luncheon Program',
#  'National Public Radio, Inc.',
#  'Nato',
#  'New European Union',
#  'Non-',
#  'Non-European Union',
#  'North Atlantic Fisheries Organization',
#  'North Atlantic Treaty Organization',
#  'OJ C 303',
#  'OPERATIONS',
#  'Observateurs/Promatraci/ Osservatori/Noverotaji/Stebetojai/Megfigyelok/Osservaturi/Waarnemers/Obserwatorz y/Observadores/Observatori/Pozorovatelia/ Opazovalci/Tarkkailijat/Observatörer',
#  'Observateurs/Promatrači/ Osservatori',
#  'Oceania Division',
#  'Office/Cabinet',
#  'Operations',
#  'Operations WK',
#  'Orient House',
#  'Oskaras Jusys',
#  'Osservaturi/Waarnemers/Obserwatorz y/Observadores/Observatori/Pozorovatelia/ Opazovalci/',
#  'PA - PE609.632v01-00',
#  'PE612.304v01',
#  'PE612.304v01-00',
#  'PE612.304v01-00 3/15',
#  'PE612.304v01-00 EN United',
#  'PE612.304v01-00 EN Наблюдатели/Observadores',
#  'PE612.304v01-00 EN Правна',
#  'PECH',
#  'PEPGO',
#  'PKK',
#  'PLACING SOLANA',
#  'POLITICAL',
#  'PPE',
#  'PREPARES',
#  'PRESENZA',
#  'PRESENZA/',
#  'PRIMA) Research and Innovation',
#  'Pal',
#  'Pan-European Pensions Group',
#  'Papadopoulos',
#  'Parliament',
#  'Partecipanti',
#  'Partnership for Research and Innovation MediMediMediMediterranean Area',
#  'Partnership for Research and Innovation the Arab Republic of Egypt',
#  'Pasta Foods',
#  'Pavel',
#  'Peadirektoraat/',
#  'Permanent Representatives Committee/Council No. Cion',
#  'Permanent Structured Cooperation (PESCO)',
#  'Permanent Structured Cooperation 16/02/2017 WK 1336 2017',
#  'PhL/at',
#  'Piraeus Marine Club Discussion',
#  'Piraeus Marine Club Discussion on Department',
#  'Pirmininkui',
#  'Plesu',
#  'Policy on Businesses',
#  'Political Editor',
#  'Political Media Engagement 2 Editor',
#  'Politico Department for Exiting the European Union Policy on Businesses',
#  'Politico Discussion on Department for Exiting the European Union Policy on Businesses',
#  'Poon',
#  'Post Bank of Iran',
#  'Postimees Print Interview',
#  'Potpredsjednik/Priekšsedetaja',
#  'Pravna',
#  'Pravna služba',
#  'Preds',
#  'Predsedstvo/Puheenjohtajisto/Presi',
#  'Predsjednik',
#  "Predsjednik/Priekšsēdētājs/ Pirmininkas/Elnök/'Chairman'/Voorzitter/Przewodniczący/Preşedinte/Predseda/Preds ednik/Puheenjohtaja/Ordförande (",
#  'Presidente/Cabinet',
#  'Presidente/Cabinet Presedinte',
#  'Presidente/Kancelář',
#  'Presidente/La',
#  'Public Register European Parliament',
#  'QVM',
#  'RC 05) Revision Action Plan',
#  'READER',
#  'REGI',
#  'REV',
#  'REV 1',
#  'REV 1 21/11/2017',
#  'REV 1 22/11/2017',
#  'REV 1 30/11/2017 2nd',
#  'REV 1 ADD 1 Compilation of Comments on',
#  'REV 1 Draft Conduct of the Call for Contribution',
#  'REV 1 Draft EU Capability Codes',
#  'REV 1 Draft EU Military Training',
#  'REV 1 Draft Framework',
#  'REV 1 Draft Military Advice',
#  'REV 1 MILITARY INPUT',
#  'REV 1 Revised Draft Military Advice',
#  'REV 2',
#  'REV 2 11/12/2017',
#  'REV 2 13/10/2017 2nd',
#  'REV 2 14/11/2017 Draft Military Advice',
#  'REV 2 Draft EU Military Training',
#  'REV 2 Draft Military Advice',
#  'REV 2 MILITARY',
#  'REV 2 Minimum Technical Requirements for Contracted',
#  'REV 2 Revised Draft Military Advice',
#  'REV 3',
#  'REV 3 17/10/2017 3rd',
#  'REV 3 17/10/2017 Draft Military Advice',
#  'REV 3 Draft Military Advice',
#  'REV 3 Third',
#  'REV 4',
#  'REV 5',
#  'ROTATING',
#  'Reference Subject Creation Date WK',
#  'Reflection Group',
#  'Republic of Algeria',
#  'Requirements Catalogue',
#  'Research',
#  'Review on Defence (CARD)',
#  'Rifkind',
#  'Riviera',
#  'Roundtable Department',
#  'S&D) Opinions',
#  'SAFE Frederic Gouarderes',
#  'SIA',
#  'SICOVAM',
#  'SIGNATURES',
#  'SMMT Discussion',
#  'SMMT Discussion on Department',
#  'SPEECH',
#  'SPG 6 Subject',
#  'STATEMENT',
#  'SUBJECT',
#  'SUMMIT',
#  'Sahel Joint Force',
#  'Sahel Joint Force WK',
#  'SakorafaSofia',
#  'SakorafaSofia Sakorafa Sofia',
#  'Sanader',
#  "Sanctions Regime against Iran The European Union's",
#  'Santander UK Department for Exiting the European Union Policy on Businesses',
#  'Santander UK Discussion on Department for Exiting the European Union Policy on Businesses',
#  'Scheussel',
#  'Schuessel',
#  'Secretariat',
#  'Security and Defence',
#  'Segretarju',
#  'Seimas',
#  'Sekretariat',
#  'Semitic',
#  'Senate',
#  'Service/ Service',
#  'Sina Bank',
#  'Smith',
#  'Social Department for',
#  'Social Enterprise UK Discussion on Department',
#  'Social Policy, Health and',
#  'Socialist Party',
#  'Solana',
#  'Spring',
#  "Spring's",
#  'State',
#  'State Peace and Development Council',
#  'State of the Union',
#  'State of the Union Address before Parliament',
#  'Stellvertreter/Asendusliikmed/Aνα πληρωτές/Substitutes/Suppléants/',
#  'Stellvertreter/Asendusliikmed/Aνα πληρωτές/Substitutes/Suppléants/Zamjenici/ Supplenti/Aizstājēji/Pavaduojantysnariai/Póttagok/Sostituti/Plaatsvervangers/Zas tępcy/',
#  'Sterling Discussion on Department for Exiting the European Union Policy on Finance',
#  'Sterling Robin Walker 2017-10-1 Roundtable',
#  'Stipe Mesic',
#  'Sun Baroness',
#  'Supleanti/Náhradníci/ Namestniki/Varajäsenet/Suppleanter Eugen Freund',
#  'System of Preferences',
#  'TEU',
#  'TFEU',
#  'THE BRITISH FOREIGN OFFICE',
#  'THE COUNCIL OF MINISTERS',
#  'THE ELECTRONIC SIGNATURE DIRECTIVE',
#  'THE EU COUNCIL',
#  'THE EU COUNCIL OF MINISTERS HAS NOTED THAT SOLANA OF SPAIN',
#  'THE EUROPEAN COMMISSION',
#  'THE EUROPEAN UNION',
#  "THE EUROPEAN UNION'S",
#  'THE HOUSE OF COMMONS',
#  'THE MANDATE OF THE',
#  'THE PROGRESS OF ELECTRONIC COMMERCE',
#  'THE REGIONAL BLOC',
#  'THE WESTERN EUROPEAN UNION',
#  'THEIR FREE MOVEMENT',
#  'TIFF',
#  'TRAN',
#  'Tass',
#  'Taverna',
#  'Teagasc',
#  'Tedeschi',
#  'Tees Valley Combined Authority Discussion on Department',
#  'Telegraph Media',
#  'The AT&T Corporation',
#  'The Associated Press',
#  'The British Telecom-AT&T',
#  'The Commission',
#  'The Common Foreign and Security Policy',
#  'The Council of the European Union',
#  'The Court',
#  'The Department for Exiting National Council for the European Union Voluntary Organisations Policy',
#  'The Directive and Regulation',
#  'The EU Committee of Regions',
#  'The EU Council',
#  'The EU Council of Ministers',
#  'The EUMC Strategic Priorities',
#  'The European Commission',
#  'The European Council',
#  'The European Court of Justice',
#  'The European Movement',
#  'The European Parliament',
#  'The European Union',
#  'The European Union Commission',
#  'The European Union Council of Ministers',
#  "The European Union's",
#  'The Financial Times Media',
#  'The Foreign Office',
#  'The Future of Manufacturing',
#  "The Future of Manufacturing in Europe'",
#  'The General Court',
#  'The House of Representatives',
#  'The Lithuanian Foreign Ministry',
#  'The Media Engagement 2 Financial Times',
#  'The Media Engagement 9 Financial Times',
#  'The NAFTA trade zone',
#  'The National Council for Voluntary Organisations Discussion on Department for Exiting the European Union Policy',
#  'The Netherlands British Chamber of Commerce Dinner Discussion on Department for Exiting the European Union Policy on Businesses',
#  'The Netherlands British Discussion',
#  'The New York Times',
#  'The Nice Treaty',
#  'The Permanent Representatives Committee',
#  'The Special Program',
#  'The Sun Media',
#  'The Sun Media Engagement Baroness Anelay',
#  'The Sun Tony Gallagher',
#  'The Treaty of Nice',
#  'The U.S. Senate',
#  'The Western European Union',
#  "The Western European Union's",
#  'The Yugoslav Foreign Ministry',
#  'Thomson Media Inc.',
#  'Times Media',
#  'Tocka UL',
#  'Torrejon',
#  'Towards',
#  'Transport, Telecommunications and Energy -- Agriculture and Fisheries -- Environment -- Education',
#  'Treasury',
#  'Treaty on European Union',
#  'U.N',
#  'U.N.',
#  'UBS Discussion',
#  'UBS Discussion on Department for Exiting',
#  'UD 13 SPG 5',
#  'UD 13 SPG 5 (',
#  'UD 16 SPG 7',
#  'UK Government',
#  'UL',
#  'UN',
#  'UN Security Council',
#  'UNAMIR',
#  'UNESCO',
#  'UNITA',
#  'UNPROFOR',
#  'US Trade Representative',
#  'Union',
#  'United Kingdom Accreditation Service',
#  'United Nations',
#  'United Nations Advance Mission',
#  'Universities',
#  'University of Oxford Discussion',
#  'University of Oxford Discussion on Department for Exiting the European Union Policy',
#  'Utkan',
#  'VAT',
#  'VATs',
#  'VIA',
#  'VP',
#  'Verts/ALE) PA - PE609.603v01',
#  'Viċi',
#  'Vladimír Maňka',
#  'Vorstand/Juhatus/Προεδρείο/Bureau/Predsjed',
#  'WEU',
#  'WEU ASSOCIATES',
#  'WEU) National Press Club',
#  'WEUSC',
#  'WHOSE COUNTRY HOLDS',
#  'WK',
#  'WK 10237 2017',
#  'WK 11112 2017 INIT 10/10/2017 Draft Military Advice',
#  'WK 11259 2017 INIT 11/10/2017 Compilation of Comments on the Draft',
#  'WK 1252 2017 INIT Draft Conduct of the Call for Contribution',
#  'WK 13087 2017',
#  'WK 1336 2017',
#  'WK 14021 2017 INIT',
#  'WK 1591',
#  'WK 1591 2017 INIT Draft Framework',
#  'WK 2689 2017',
#  'WK 2735 2017',
#  'WK 3497 2017 INIT Election',
#  'WK 521',
#  'WK 521 2017',
#  'WK 698 2017 INIT MILITARY INPUT',
#  'WTO',
#  'WWF UK Discussion on Anelay 3 Department',
#  'WWF UK Discussion on Department',
#  'Warsaw Pact',
#  'Washington Post',
#  'Weber',
#  'Western European Union',
#  'Whisk(e)y',
#  'Xinhua',
#  'Xinhua)',
#  'Young UK Department for Exiting',
#  'Youth Affairs Council',
#  'Zastupnici/Deputati',
#  'Zastupnici/Deputati/Deputati/Nariai/Képviselõk/Membri/Leden/Poslowie/Depu',
#  '[Workers Welfare Bank',
#  'a College of Cardinals',
#  'a European Council',
#  'a Joint Report',
#  'another International Organization for Migration',
#  'culture,',
#  'hdibon@ilog.fr',
#  'tajomníka/Urad',
#  'the "Environment Council',
#  'the "General Affairs and External Relations Council',
#  'the Abolition of Long-distance Transport of Animals for Slaughter',
#  'the Accession Treaty',
#  'the American Jewish Committee',
#  'the Association of Foreign Banks Discussion on Department for Exiting the European Union Policy on Banking Robin Walker',
#  'the Association of Southeast Asian Nations',
#  'the Austria Press Agency',
#  'the Austrian Foreign Ministry',
#  'the Austrian Parliament',
#  'the Austrian Press Agency',
#  'the Austrian Press and Information Service',
#  'the Automotive Sector Discussion on Department for Exiting the European Union Policy on Automotive Industry Robin Walker',
#  'the Baltic Assembly',
#  'the British Foreign Office',
#  'the British-Swedish Chamber of Commerce Discussion on Department for Exiting the European Union Policy Baroness Anelay',
#  'the Central Bank',
#  "the Chair(wo)man/Sur l'invitation du président/ Na",
#  'the Chemistry Growth Department for Exiting Partnership',
#  'the Chemistry Growth Partnership Discussion on Department for Exiting the European Union',
#  'the Committee of Permanent Representatives of the Member States',
#  'the Common Agricultural Policy.',
#  'the Common Foreign and Security Policy',
#  'the Common Position',
#  'the Concept Note on Operational Planning and Conduct Capabilities for CSDP Missions and Operations',
#  'the Concept Note on Operational Planning and Conduct Capabilities for CSDP Missions and Operations 14/02/2017',
#  'the Concept Note on Operational Planning and Conduct Capabilities for CSDP Missions and Operations 15/02/2017 WK 1336 2017',
#  'the Concept Note on the Operational Planning and Conduct Capabilities for CSDP Missions and Operations',
#  'the Congress of European Rabbis',
#  'the Constitutional Affairs Committee',
#  'the Contact Group',
#  'the Convention of the Future of Europe',
#  'the Convention on the Future of Europe',
#  'the Council',
#  'the Council Presidency',
#  'the Council and the Commission',
#  'the Council for the consent',
#  'the Council of 11 August 2012',
#  'the Council of 16 December 2015',
#  "the Council of Europe's",
#  'the Council of General Affairs',
#  'the Council of Ministers',
#  'the Council of Ministers -',
#  'the Council of Ministers Committee of Permanent Representatives',
#  'the Council of the European Union',
#  'the Council of the Union',
#  'the Council on European business statistics',
#  'the Court of First Instance',
#  'the Court of Justice',
#  'the Court of Session',
#  'the Defence sector Discussion on Department for Exiting the European Union Policy on EU Exit',
#  'the Delegation of the European Commission',
#  "the Democratic People's Republic of Korea",
#  'the Department for Exiting Association of Foreign the European Union Banks Policy on Banking Robin Walker',
#  'the Department for Exiting Automotive Sector the European Union Policy on Automotive Industry Robin Walker',
#  'the Department for Exiting British Ports',
#  'the Department for Exiting British-Swedish Chamber of the European Union Commerce Policy Baroness 2017-10-0 Lithuanian Business Discussion on Anelay 4',
#  'the Department for Exiting Defence',
#  'the Department for Exiting Energy, Construction',
#  'the Department for Exiting Freight Transport the European Union Association Policy on Customs and Trade',
#  'the Department for Exiting Manufacturing',
#  'the Department for Exiting Universities, Research',
#  'the Digital Terrain Elevation Data (DTED) and',
#  'the Draft Military Advice',
#  'the Dutch Embassy',
#  'the EEAS Food for Thought Paper:',
#  'the EEAS Food for Thought Paper: Implementing the EU Global Strategy',
#  'the EU Accession Treaty',
#  'the EU Commission',
#  "the EU Commission's",
#  'the EU Committee',
#  'the EU Committee on Economic and Monetary Affairs',
#  'the EU Council',
#  'the EU Council of General Affairs',
#  'the EU Council of Ministers',
#  "the EU Council''",
#  "the EU Council's",
#  'the EU Crisis Management Military Exercise',
#  'the EU Intergovernmental Conference',
#  'the EU Treaty',
#  "the EU Treaty's",
#  'the Energy, Construction and Transport sectors Discussion on Department for Exiting the European Union Policy on Businesses',
#  'the European Atomic Energy Community',
#  'the European Commission',
#  'the European Commission Delegation',
#  'the European Commission Press Office',
#  'the European Commission Washington Delegation',
#  'the European Community',
#  'the European Community Information Service',
#  'the European Corporate Governance Institute',
#  'the European Council',
#  'the European Councils',
#  'the European Court',
#  'the European Court of Justice',
#  'the European Defense and Security Identity, Europe',
#  'the European Development Fund',
#  'the European Economic Community',
#  'the European Investment Bank',
#  'the European Jewish Congress',
#  'the European Parliament',
#  'the European Parliament 1',
#  'the European Union',
#  "the European Union ('",
#  'the European Union - Request',
#  'the European Union Agreement',
#  'the European Union Brussels',
#  'the European Union Council',
#  'the European Union Council issued Directive',
#  'the European Union Council of Ministers',
#  'the European Union Court of Justice',
#  'the European Union Education Sector Policy on Higher Education',
#  'the European Union Financial Regulatory: Policy on Finance Shearman',
#  'the European Union GILLIAN A BRIGGS',
#  'the European Union Military Committee',
#  'the European Union Policy',
#  'the European Union Policy Baroness',
#  'the European Union Policy Baroness Anelay',
#  'the European Union Policy on Aerospace Robin Walker',
#  'the European Union Policy on Automotive',
#  'the European Union Policy on Businesses',
#  'the European Union Policy on Consumers Robin Walker',
#  'the European Union Policy on Energy Robin Walker',
#  'the European Union Policy on Life Sciences',
#  'the European Union Policy on Manufacturing Robin Walker',
#  'the European Union Transport',
#  "the European Union'",
#  "the European Union's",
#  "the European Union's Treaty of Rome",
#  'the European Union(EU',
#  'the European Venture Capital Association',
#  'the Federal Republic of Yugoslavia',
#  "the Foreign Ministry's",
#  "the Foreign Ministry's Economy Department",
#  'the Free Aceh Movement',
#  'the Freight Transport Association Discussion on Department for Exiting the European Union Policy on Customs and Trade',
#  'the French Foreign Ministry',
#  'the G-7',
#  'the G-8 countries',
#  'the General Court',
#  'the General Court of',
#  'the General Court of the European Union',
#  "the General Court of the European Union's",
#  'the General Secretariat of the Council to the European Union Military Committee',
#  'the Global Financial Department for Exiting Institutions Advisory',
#  'the Global Financial Institutions Advisory and Financial Regulatory',
#  'the Greek Cypriots',
#  'the Gulf Cooperation Council',
#  'the Inland Revenue',
#  'the Inter-Governmental Conference',
#  'the Intergovernmental Conference',
#  'the International Accounting Standards Board',
#  'the International Herald Tribune',
#  'the International Labor Organization',
#  'the International Organization for Migration',
#  'the Iranian Government',
#  'the Islamic Republic of Iran',
#  "the Islamic Republic of Iran's",
#  'the League of Nations',
#  'the Madrid European Council',
#  'the Manufacturing sector Discussion on Department for Exiting the European Union Policy on Manufacturing Robin Walker',
#  'the Mexican Senate',
#  'the Middle East Peace Process',
#  'the New York Times',
#  'the North American Free Trade Agreement',
#  'the North Atlantic Alliance',
#  'the North Atlantic Council',
#  'the North Atlantic Treaty Organisation',
#  'the North Atlantic Treaty Organization',
#  'the North Atlantic Treaty Prganization',
#  'the Official Journal',
#  'the Operational Planning and Conduct Capabilities for CSDP Missions and Operations 06/02/2017',
#  'the Organization for Security and Co-operation',
#  'the Organization for Security and Cooperation in Europe',
#  'the Orient House',
#  'the Palestinian Authority',
#  'the Parliament Assembly',
#  'the Partnership for Research and Innovation',
#  "the People's Democratic",
#  "the People's Democratic Republic Algeria in Partnership",
#  "the People's Democratic Republic Algeria in Partnership for Research and Innovation",
#  "the People's Democratic Republic of Algeria",
#  'the Preservation and Protection of Cultural Heritage',
#  'the Public Court',
#  'the Report of the Competitiveness Advisory Group',
#  'the Risk Capital Action Plan',
#  'the Russian ITAR',
#  'the Securities Industry Association',
#  'the Shan Nationalities League for Democracy',
#  'the Social Affairs Council',
#  'the Socialist Party',
#  'the South African Development Community',
#  'the Space Imaging GeoMatics Application (SIGMA',
#  'the Swedish Foreign Ministry',
#  'the Swiss Confederation',
#  'the Trade and Industry',
#  'the Trans-European Networks',
#  'the Treaty of Lisbon',
#  'the U.N. General Assembly',
#  'the U.N. Security Council',
#  'the U.S. Sixth Fleet',
#  'the U.S. State Department Southern European Affairs',
#  'the US Senate',
#  'the Union (Copenhagen European Council',
#  'the United Nations',
#  'the United Nations High Commission for Refugees (UNHCR',
#  'the United States Administration',
#  'the United States Government',
#  'the WEU Ministerial Council',
#  'the West European Union',
#  'the West Mostar (Bosnian Croat',
#  'the Western European Union',
#  'the Western European Union Satellite Centre',
#  'the Working Party',
#  'the World Trade Organization',
#  "the World Trade Organization's",
#  'the world Trade Organization',
#  'this Common Position',
#  'uzaicinājuma/Pirmininkui',
#  'Председател/Presidente/Predseda/Formand/Vorsitzender',
#  'Председател/Presidente/Předseda/Formand/Vorsitzender/',
#  'Тoчка',
#  'Членове/Diputados/Poslanci/Medlemmer/Mitglieder/Parlamendiliikmed/Μέλη/Members'}

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(df['TEXT'][2])

# %%
type(nlp) == spacy.lang.en.English
# Out:
# True
