# %% [markdown]
# # Coding actors
#
# Actors are counted using NER. Two categories are then used: PERSON and ORGANIZATION.
#
# The process has three steps:
# 1. Summarising the unique actors and listing these in a separate data file
# 2. Coding them (See separate notebook `Coding actors.ipynb`)
# 3. Counting them automatically
#
# #### Category selection
# The choice is made to select only PERSON and ORGANIZATION for coding. The CoreNLP NER is good enough to separate these. If they are confused, they often seem to fit in each other's categories. The MISC category catches whatever is left that is obviously not a date, number, ordinal or location. If there are false negatives, they should be there. The category, however, is fairly large. Therefore, for initial coding the PERSON and ORGANIZATION tags should suffice.
#
# #### Counting
# Counting is rather tedious in this case, because names of actors might overlap and therefore lead to double counting. Consider the following few options. These strings overlap in multiple situation. Firstly, all overlap with 'Council', leading to double counting. Secondly, 'Council of Ministers' overlaps with 'Council of Ministers Committee of Permanent Representatives', leading to triple counting.
#
# ```
# Council
# Council Presidency
# Council of 16
# Council of Europe
# Council of General Affairs
# Council of Ministers
# Council of Ministers Committee of Permanent Representatives
# Council of the European Union
# Council of the Union
# ```
#
# This is overcome using `re.findall()`, which finds all non-overlapping matches. The regular expression is built up using or statements (e.g. `'Council Presidency|Council'`), where regex **takes only the first match** from the pattern if they overlap. Therefore, to find the unique matches, ignoring overlapping substrings, the different entities have to be sorted by length before bulding the pattern. To clarify, consider the following:
#
# ```Python
# sentence = 'This sentence is about the Council Presidency'
# print(re.findall('Council Presidency|Council',sentence))
# # ['Council Presidency']
# print(re.findall('Council|Council Presidency',sentence))
# # ['Council']
# ```
#
# The former is correct, hence the sorting. The pattern is precompiled in order to save computation time.

# %%
import pandas as pd
import json
from ner_methods import *
import spacy
import re
import codingtools

spacy_model = 'nl_core_news_sm'
settings_file = 'D:/thesis/settings - nl.json'

# %%
#Preparation

#Read settings
settings = json.loads(open(settings_file).read())["settings"]

#Read data
df = pd.read_csv(settings['data_csv'])

# %%
#Unique named entities
uniqueEntities = set()

counter = 0
errorList = []

nlp = spacy.load(spacy_model)
for text in df['TEXT']:
    try: #Sometimes texts give errors, e.g. when different alphabets are used. Therefore list those.
        uniqueEntities.update(getUniqueEntities(text,nlp))
    except:
        errorList.append(str(counter))
    counter += 1

print("Errors occurred on indices:",", ".join(errorList))

##Sort entities into categories
entity_map = {}

for (entity,entity_type) in uniqueEntities:
    if entity_type not in entity_map: #Set element to the correct data format to then add elements
        entity_map[entity_type] = set()
        
    entity_map[entity_type].add(entity)
    
print("Entities were found in the following categories:",", ".join(entity_map.keys()))

##Save output of uncoded actors to CSV, sorted alphabetically
with open(settings['person_csv'],'w+',encoding = 'utf-8') as f:
    for person in sorted(entity_map['PER']):
        f.write(person+'\n')

with open(settings['org_csv'],'w+',encoding = 'utf-8') as f:
    for org in sorted(entity_map['ORG']):
        f.write(org+'\n')
# Out:
# Errors occurred on indices:
# Entities were found in the following categories: MISC, ORG, LOC, PER
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a91ea8b4e985> in <module>()
#      28 ##Save output of uncoded actors to CSV, sorted alphabetically
#      29 with open(settings['person_csv'],'w+',encoding = 'utf-8') as f:
# ---> 30     for person in sorted(entity_map['PERSON']):
#      31         f.write(person+'\n')
#      32
#
# KeyError: 'PERSON'

# %%
# Counting actors

# Assuming coding is done using the extension from codingtools, this initiates a copy of that instance of codingTool
with open(settings['codes'], 'r', encoding = 'utf-8') as f:
    coding = codingtools.from_json(f.read())
codes = coding.coded
categories = coding.categories

#As mentioned above, keys should be sorted by length for correct matching of overlapping cases
keys = sorted(list(codes.keys()), key = len, reverse = True)
keys_pattern = re.compile('|'.join(keys))

df['ACTORS'] = df['TEXT'].map(lambda x: set(re.findall(keys_pattern,x)))

for category in categories:
    df['count_'+category] = df['ACTORS'].map(lambda x: len([1 for element in x if (codes[element] == category)]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d54986f3e2d5> in <module>()
#       2
#       3 # Assuming coding is done using the extension from codingtools, this initiates a copy of that instance of codingTool
# ----> 4 with open(settings['codes'], 'r', encoding = 'utf-8') as f:
#       5     coding = codingtools.from_json(f.read())
#       6 codes = coding.coded
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/thesis/nl/actors/coded.json'

# %%
#Output to csv
df.to_csv(settings['data_csv'])

# %%
len(entity_map['ORG'])
# Out:
# 1161

# %%
doc = nlp(df['TEXT'][2])

# %%
import numpy as np
df[[isinstance(x,float) for x in df['MEDIUM']]]
# Out:
#       Unnamed: 0                                             BYLINE  \
# 0              0                                       BERT LANTING
# 1              1                                                NaN
# 2              2                                                NaN
# 3              3  Ruurd Ubels nd.nl/economie beeld anp / Remko d...
# 4              4                        Van een onzer verslaggevers
# 5              5                        Van een onzer verslaggevers
# 6              6  Gabor Landman · directeur van de Stichting Eur...
# 7              7                                                NaN
# 8              8                                                NaN
# 9              9                                                NaN
# 10            10                                                NaN
# 11            11                                                NaN
# 12            12                                                NaN
# 13            13                                                NaN
# 14            14                                                NaN
# 15            15                                                NaN
# 16            16                                                NaN
# 17            17                                                NaN
# 18            18                                                NaN
# 19            19                                                NaN
# 20            20                                                NaN
# 21            21                                                NaN
# 22            22                                                NaN
# 23            23                                                NaN
# 24            24                                                NaN
# 25            25                                       Jan Braakman
# 26            26                                                NaN
# 27            27                                 Van onze redacteur
# 28            28                                  ATZE JAN DE VRIES
# 29            29                                                NaN
# ...          ...                                                ...
# 1532        1532                                                ANP
# 1533        1533             Door onze correspondent; René Moerland
# 1534        1534                            Door onze correspondent
# 1535        1535                                                NaN
# 1536        1536           Door onze correspondent; Petra de Koning
# 1537        1537                                                NaN
# 1538        1538                                                NaN
# 1540        1540                         Door een onzer redacteuren
# 1541        1541                                                NaN
# 1542        1542                          Door onze correspondenten
# 1543        1543                                                NaN
# 1544        1544                                    Mark Kranenburg
# 1546        1546                                                NaN
# 1547        1547                                                NaN
# 1548        1548                                                NaN
# 1549        1549                                   HAN DIRK HEKKING
# 1550        1550                                   HAN DIRK HEKKING
# 1551        1551                                    Mark Kranenburg
# 1552        1552                                                NaN
# 1553        1553                                                NaN
# 1554        1554                                                NaN
# 1555        1555  Angela Merkel, José Barroso en Hans-Gert Pötte...
# 1556        1556                                        Ahmet Olgun
# 1557        1557                                                NaN
# 1558        1558                                                NaN
# 1559        1559                                    Mark Kranenburg
# 1560        1560                                    Mark Kranenburg
# 1561        1561                                       JACK VAN HAM
# 1575        1575                                                NaN
# 1576        1576                                    Mark Kranenburg
#
#                    DATE                  DATELINE  \
# 0      28 december 2017                       NaN
# 1      28 december 2017                       NaN
# 2      28 december 2017                       NaN
# 3      14 november 2017                       NaN
# 4       17 oktober 2017                       NaN
# 5       17 oktober 2017                       NaN
# 6        5 oktober 2017                       NaN
# 7     15 september 2017                       NaN
# 8      16 augustus 2017                       NaN
# 9      16 augustus 2017                       NaN
# 10     16 augustus 2017                       NaN
# 11     16 augustus 2017                       NaN
# 12     16 augustus 2017                       NaN
# 13     16 augustus 2017                       NaN
# 14     16 augustus 2017                       NaN
# 15     16 augustus 2017                       NaN
# 16     16 augustus 2017                       NaN
# 17     16 augustus 2017                       NaN
# 18     16 augustus 2017                       NaN
# 19     16 augustus 2017                       NaN
# 20     16 augustus 2017                       NaN
# 21     16 augustus 2017                       NaN
# 22     16 augustus 2017                       NaN
# 23     16 augustus 2017                       NaN
# 24         31 juli 2017                       NaN
# 25        24 maart 2017                       NaN
# 26        11 maart 2017                       NaN
# 27      20 januari 2017                       NaN
# 28      20 januari 2017                       NaN
# 29      20 januari 2017                       NaN
# ...                 ...                       ...
# 1532    august 11, 2008                   BRUSSEL
# 1533      july 11, 2008          Parijs, 11 juli.
# 1534       july 1, 2008           Parijs, 1 juli.
# 1535        4 juni 2008                       NaN
# 1536       may 26, 2008          Brussel, 26 mei.
# 1537      24 april 2008                       NaN
# 1538      24 april 2008                  DEN HAAG
# 1540     april 23, 2008       DEN HAAG, 23 APRIL.
# 1541       5 march 2008                       NaN
# 1542      march 4, 2008  Berlijn/Parijs, 4 maart.
# 1543  february 23, 2008                       NaN
# 1544   december 8, 2007                       NaN
# 1546    october 9, 2007                       NaN
# 1547  20 september 2007                       NaN
# 1548  12 september 2007                       NaN
# 1549      3 august 2007                       NaN
# 1550       28 june 2007                       NaN
# 1551      june 25, 2007         BRUSSEL, 25 JUNI.
# 1552     march 30, 2007                       NaN
# 1553     march 26, 2007                       NaN
# 1554     march 26, 2007                       NaN
# 1555     march 26, 2007                       NaN
# 1556       9 march 2007                  Den Haag
# 1557   28 february 2007                       NaN
# 1558  february 27, 2007         Brussel, 27 febr.
# 1559   february 8, 2007          BRUSSEL, 8 febr.
# 1560    8 february 2007                   BRUSSEL
# 1561    23 january 2007                       NaN
# 1575  december 14, 2006          BRUSSEL, 14 DEC.
# 1576   december 9, 2006           BRUSSEL, 9 DEC.
#
#                                                HEADLINE HIGHLIGHT  LANGUAGE  \
# 0                                       Europa is terug       NaN       NaN
# 1      rechtsstaat Europese Unie dient pal te staan ...       NaN       NaN
# 2      rechtsstaat Europese Unie dient pal te staan ...       NaN       NaN
# 3     'Ik ken geen Brits bedrijf dat uit Europese Un...       NaN       NaN
# 4             Scheurende tuinmuur blijkt niet onderheid       NaN       NaN
# 5             Scheurende tuinmuur blijkt niet onderheid       NaN       NaN
# 6              Oekraïne heeft niks met Europese waarden       NaN       NaN
# 7               Nuttige voorzet voor noodzakelijk debat       NaN       NaN
# 8                                                  Kort       NaN       NaN
# 9                                                  Kort       NaN       NaN
# 10                                                 Kort       NaN       NaN
# 11                                                 Kort       NaN       NaN
# 12                                                 Kort       NaN       NaN
# 13                                                 Kort       NaN       NaN
# 14                                                 Kort       NaN       NaN
# 15                                                 Kort       NaN       NaN
# 16                 Moerdijk Editie; Oosterhout Editi...       NaN       NaN
# 17                         Air Berlin in acute geldnood       NaN       NaN
# 18                  Editie; Meierij Editie; Oss Edit...       NaN       NaN
# 19                Editie; Oldenzaal Editie; Tubberge...       NaN       NaN
# 20                    Flevoland Editie; Lochem Editi...       NaN       NaN
# 21                                  Editie; Zuid Editie       NaN       NaN
# 22                         Air Berlin in acute geldnood       NaN       NaN
# 23    Groot-Brittannië wil tijdelijk een douane-unie...       NaN       NaN
# 24                     Hard debat met Oost-Europa nodig       NaN       NaN
# 25    Jarige Europese Unie moet hard nadenken over e...       NaN       NaN
# 26                               EU bezorgd over Balkan       NaN       NaN
# 27                             Rutte: geen EU-romantiek       NaN       NaN
# 28                                  Lessen voor de Unie       NaN       NaN
# 29                                  Lessen voor de Unie       NaN       NaN
# ...                                                 ...       ...       ...
# 1532                    'EU heeft veel meer ambtenaren'       NaN       NaN
# 1533  Sarkozy zet door met nieuw verbond; Mediterran...       NaN       NaN
# 1534  Parijs wil bouwen aan een 'ander Europa'; EU-v...       NaN       NaN
# 1535  Unieke Europese Unie moet op eigen benen leren...       NaN       NaN
# 1536  Polen kijkt over oostgrens EU; Plan voor inten...       NaN       NaN
# 1537                    Slovenië bepleit uitbreiding EU       NaN       NaN
# 1538         Nederland wil macht EU-voorzitter beperken       NaN       NaN
# 1540   Nederland wil macht van Europese leider beperken       NaN       NaN
# 1541               SECTION: NEDERLAND & EUROPA; Blz. 10       NaN       NaN
# 1542  Compromis over omstreden plan Sarkozy; Duitsla...       NaN       NaN
# 1543   De Europese Unie heeft een aansprekend gezich...       NaN       NaN
# 1544  Zo blijft de Europese eenwording één groot mis...       NaN       NaN
# 1546     Verstandig dat er geen referendum komt; Europa       NaN       NaN
# 1547               SECTION: NEDERLAND & EUROPA; Blz. 13       NaN       NaN
# 1548               SECTION: NEDERLAND & EUROPA; Blz. 10       NaN       NaN
# 1549                                       Blauwe kaart       NaN       NaN
# 1550  Rehn raadt staken toetredingsberaad Turkije af...       NaN       NaN
# 1551               Rode draad is wat Europa nu níét mag       NaN       NaN
# 1552                       D-Midden ; G-West ; G-Mid...       NaN       NaN
# 1553                             Verklaring van Berlijn       NaN       NaN
# 1554         Europa is onze gemeenschappelijke toekomst       NaN       NaN
# 1555      Wij hebben in Europa het geluk om één te zijn       NaN       NaN
# 1556   Zelfs in de kroeg praten we erover; Studenten...       NaN       NaN
# 1557               SECTION: NEDERLAND & EUROPA; Blz. 10       NaN       NaN
# 1558                  Europa dichtbij doelen 'Lissabon'       NaN       NaN
# 1559  Brussels stempel op Haags akkoord; Van begroti...       NaN       NaN
# 1560   Brussels stempel op Haags akkoord; Van begrot...       NaN       NaN
# 1561                  Europa vergroot armoede in Afrika       NaN       NaN
# 1575                 Verdeeldheid over satellietsysteem       NaN       NaN
# 1576              Verdeeldheid EU over Turkije 'risico'       NaN       NaN
#
#       LENGTH           LOAD-DATE MEDIUM                      SECTION  \
# 0        560    27 December 2017    NaN     Opinie en Debat; Blz. 21
# 1        569   December 27, 2017    NaN              Opinie; Blz. 18
# 2        569   December 28, 2017    NaN              Opinie; Blz. 18
# 3        530    13 November 2017    NaN                     Blz. 2,3
# 4        968    14 November 2017    NaN           --Maak een keuze--
# 5        968    14 November 2017    NaN           --Maak een keuze--
# 6         -1      4 October 2017    NaN                          NaN
# 7        372  September 14, 2017    NaN        IN HET NIEUWS; Blz. 2
# 8        297      15 August 2017    NaN            Economie; Blz. 16
# 9        297      15 August 2017    NaN            Economie; Blz. 16
# 10       297      15 August 2017    NaN            Economie; Blz. 16
# 11       297      15 August 2017    NaN            Economie; Blz. 16
# 12       297      15 August 2017    NaN            Economie; Blz. 16
# 13       297      15 August 2017    NaN            Economie; Blz. 16
# 14       297      15 August 2017    NaN            Economie; Blz. 16
# 15       297      15 August 2017    NaN            Economie; Blz. 16
# 16        -1      16 August 2017    NaN                          NaN
# 17       287      16 August 2017    NaN            Algemeen; Blz. 16
# 18        -1      16 August 2017    NaN                          NaN
# 19        -1      15 August 2017    NaN                          NaN
# 20        -1      16 August 2017    NaN                          NaN
# 21        -1      15 August 2017    NaN                          NaN
# 22       287      16 August 2017    NaN            Algemeen; Blz. 16
# 23       309      15 August 2017    NaN          Buitenland; Blz. 10
# 24       473        30 July 2017    NaN              Opinie; Blz. 18
# 25       422      March 24, 2017    NaN           BB2 Ed. 31 Nr. 110
# 26       222       10 March 2017    NaN               Geen; Blz. 2,3
# 27       235    January 19, 2017    NaN  ECONOMIE & POLITIEK; Blz. 6
# 28       445     19 January 2017    NaN        In Het Nieuws; Blz. 2
# 29       448     19 January 2017    NaN        In Het Nieuws; Blz. 2
# ...      ...                 ...    ...                          ...
# 1532     181     August 10, 2008    NaN           BUITENLAND; Blz. 4
# 1533    1196       July 11, 2008    NaN           BUITENLAND; Blz. 5
# 1534     353        July 1, 2008    NaN          BUITENLAND; Blz. 05
# 1535     891        June 3, 2008    NaN               OPTIEK; Blz. 9
# 1536     470        May 26, 2008    NaN           BUITENLAND; Blz. 5
# 1537     273      April 23, 2008    NaN  ECONOMIE & POLITIEK; Blz. 4
# 1538     349       24 April 2008    NaN  NEDERLAND & EUROPA; Blz. 11
# 1540     418      April 23, 2008    NaN           BINNENLAND; Blz. 2
# 1541     308        5 March 2008    NaN                          NaN
# 1542     545       March 4, 2008    NaN          BUITENLAND; Blz. 05
# 1543     420   February 22, 2008    NaN            VANDAAG; Blz. 2-3
# 1544    1660    December 7, 2007    NaN      OPINIE & DEBAT; Blz. 17
# 1546     560     October 9, 2007    NaN           BIBU/ECO; Blz. 106
# 1547     236   20 September 2007    NaN                          NaN
# 1548     323   12 September 2007    NaN                          NaN
# 1549     439      13 August 2007    NaN                OPTIEK; Pg. 7
# 1550     921        27 June 2007    NaN  ECONOMIE EN POLITIEK; Pg. 5
# 1551     666       June 25, 2007    NaN           VOORPAGINA; Blz. 1
# 1552      -1      March 30, 2007    NaN                          NaN
