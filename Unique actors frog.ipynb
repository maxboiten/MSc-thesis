# %%
from sqlite_db import thesisDB
import json
from unidecode import unidecode
import re
from codingtools import DisambiguationTool

db_file = 'D:/thesis/nl/data.db'
actor_file = 'D:/thesis/nl/actors/tobecoded.csv'
db = thesisDB(db_file)

# %%
##Get entities from the database

ents = db.getEntities()
unique_ents = set()
for rowid, ent, docid, ent_type in ents:
    if ent_type in ['PER','ORG']:
        unique_ents.add((ent,ent_type))
ents.close()

# %% [markdown]
# ### Counting
# At this point, coding should be done. This includes the following subtasks:
# 1. Disambiguation. Solve duplicates into a map that collects all formulations of one entity with its nominal entity. For example, the database contains multiple phrasings of Theresa May, sometimes as 'May', sometimes as 'Theresa May'. These need to be collapsed in order to identify unique actors per article. Main problem is that Ï need to keep track of every change made, so I can collapse everything on the document level before the final counting task as well.
# 2. Coding. Code according to the EES media study codebook. For multiple occurrences form disambiguation, only code the nominal entity and then map the code to the others when counting.
# 3. Counting.
#   1. Construct map with key (ent,ent_type) and code as value.
#   2. Get set of unique entities (collapsed using disambiguation map) for every document
#   3. Code every unique entity using the codes map

# %%
#Step 1 Disambiguation map, automatic part
#Map set up as if nothing is changed between names
disambiguation_map = {k:k for k in unique_ents}

#Remove duplicate spelling from accents
disambiguation_map = {k:(unidecode(ent),ent_type) for k,(ent,ent_type) in disambiguation_map.items()}

#Remove lowercase words, if applicable
lcword = re.compile('^[a-z]+ ') #lowercase word at start of string
wrong_whitespace = re.compile('(?<= ) |^ | $|^[^A-Za-z]+(?=[A-Za-z])|(?<=[^A-Za-z])[^A-Za-z]+')
    #Remaining whitespace after lowercase words are removed: 
    #if preceded by another whitespace, start of string, end of string, non-alphabetical characters at start or end
disambiguation_map = {k:(re.sub(lcword,'',ent),ent_type) for k,(ent,ent_type) in disambiguation_map.items()}
disambiguation_map = {k:(re.sub(wrong_whitespace,'',ent),ent_type) for k,(ent,ent_type) in disambiguation_map.items()}

# %%
#Step 2 Disambiguation by hand
#Guide: Type the root entity if it is not yet the root entity. For people: firstname + last name. Click None if not an entity.
tool = DisambiguationTool(disambiguation_map)
tool.startWorking()
# Out:
# A Jupyter Widget

# %%
#Step 3A Get unique entities per document
ents = db.getEntities()
unique_ents_corpus = []
unique_ents_doc = set()

currentDoc = 1

for rowid, ent, docid, ent_type in ents:
    if docid != currentDoc:
        unique_ents_corpus.append(unique_ents_doc)
        unique_ents_doc = set()
        currentDoc = docid
    if ent_type in ['PER','ORG']:
        unique_ents_doc.add(disambiguation_map[(ent,ent_type)])
unique_ents_corpus.append(unique_ents_doc)

# %%
import pickle

# %%
pickle_name = 'tool_progress.p'
pickle.dump(tool,open(pickle_name,'wb'))
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-10-2925fefd56a9> in <module>()
#       1 pickle_name = 'tool_progress.p'
# ----> 2 pickle.dump(tool,open(pickle_name,'wb'))
#
# PicklingError: Can't pickle <built-in function input>: it's not the same object as builtins.input

# %%
tool.__dict__
# Out:
# {'disambiguated': Text(value='Adami', description='Root:', placeholder='Type something'),
#  'map': {('Raffarin', 'PER'): ('Raffarin', 'PER'),
#   ('Camerons', 'PER'): ('Camerons', 'PER'),
#   ('Kok', 'PER'): ('Kok', 'PER'),
#   ('EQU', 'ORG'): ('EQU', 'ORG'),
#   ('Binnema', 'PER'): ('Binnema', 'PER'),
#   ('CDU', 'ORG'): ('CDU', 'ORG'),
#   ('Wenceslas Plein', 'PER'): ('Wenceslas Plein', 'PER'),
#   ('OCHA', 'PER'): ('OCHA', 'PER'),
#   ('JACCO VAN', 'PER'): ('JACCO VAN', 'PER'),
#   ('Victor', 'PER'): ('Victor', 'PER'),
#   ('Volgens Bolkestein', 'PER'): ('Volgens Bolkestein', 'PER'),
#   ('NRC', 'ORG'): ('NRC', 'ORG'),
#   ('Derk Jan Eppink', 'PER'): ('Derk Jan Eppink', 'PER'),
#   ('Berlage', 'PER'): ('Berlage', 'PER'),
#   ('Trumps', 'PER'): ('Trumps', 'PER'),
#   ('René van de Linden', 'PER'): ('Rene van de Linden', 'PER'),
#   ('Charles Taylor', 'PER'): ('Charles Taylor', 'PER'),
#   ('David Kusin', 'PER'): ('David Kusin', 'PER'),
#   ('Bommeljé', 'PER'): ('Bommelje', 'PER'),
#   ('KOK EN', 'ORG'): ('KOK EN', 'ORG'),
#   ('Europese Gemeenschap', 'ORG'): ('Europese Gemeenschap', 'ORG'),
#   ('Fonds', 'ORG'): ('Fonds', 'ORG'),
#   ('Bondsdag', 'ORG'): ('Bondsdag', 'ORG'),
#   ('Veiligheidsraad', 'ORG'): ('Veiligheidsraad', 'ORG'),
#   ('Jan-Willem Bertens', 'PER'): ('Jan-Willem Bertens', 'PER'),
#   ('Europese Gemeenschap voor Kolen en',
#    'ORG'): ('Europese Gemeenschap voor Kolen en', 'ORG'),
#   ('Kemal Ataturk', 'PER'): ('Kemal Ataturk', 'PER'),
#   ('Finlands', 'PER'): ('Finlands', 'PER'),
#   ('José Socrates', 'PER'): ('Jose Socrates', 'PER'),
#   ('Rabobank', 'ORG'): ('Rabobank', 'ORG'),
#   ('Zijlstra', 'PER'): ('Zijlstra', 'PER'),
#   ('Theo van den Doel', 'PER'): ('Theo van den Doel', 'PER'),
#   ('Monetaire Unie', 'ORG'): ('Monetaire Unie', 'ORG'),
#   ('Verhagen', 'PER'): ('Verhagen', 'PER'),
#   ('EVA', 'ORG'): ('EVA', 'ORG'),
#   ('Yvonne Hofs', 'PER'): ('Yvonne Hofs', 'PER'),
#   ('Leefbaar', 'ORG'): ('Leefbaar', 'ORG'),
#   ('Karl Lamers', 'PER'): ('Karl Lamers', 'PER'),
#   ('Steichen', 'PER'): ('Steichen', 'PER'),
#   ('Tubantia', 'ORG'): ('Tubantia', 'ORG'),
#   ('Chris de Visser', 'PER'): ('Chris de Visser', 'PER'),
#   ('Michel', 'PER'): ('Michel', 'PER'),
#   ('DOUBLE_QUOTE Wallström', 'PER'): ('DOUBLE_QUOTE Wallstrom', 'PER'),
#   ('Annan', 'PER'): ('Annan', 'PER'),
#   ('Franco Frattini', 'PER'): ('Franco Frattini', 'PER'),
#   ('Gunter Verheugen', 'PER'): ('Gunter Verheugen', 'PER'),
#   ('Eimert van Middelkoop', 'PER'): ('Eimert van Middelkoop', 'PER'),
#   ('Klaus', 'PER'): ('Klaus', 'PER'),
#   ('Edward Heath', 'PER'): ('Edward Heath', 'PER'),
#   ('FBI', 'ORG'): ('FBI', 'ORG'),
#   ('Solana', 'PER'): ('Solana', 'PER'),
#   ('Adami', 'PER'): ('Adami', 'PER'),
#   ('Mubarak', 'PER'): ('Mubarak', 'PER'),
#   ('Kranten', 'ORG'): ('Kranten', 'ORG'),
#   ('Jan Orbie', 'PER'): ('Jan Orbie', 'PER'),
#   ('ANP', 'ORG'): ('ANP', 'ORG'),
#   ('Nicolas Sarkozy', 'PER'): ('Nicolas Sarkozy', 'PER'),
#   ('Albanie', 'PER'): ('Albanie', 'PER'),
#   ('VWEU', 'ORG'): ('VWEU', 'ORG'),
#   ('Fl', 'ORG'): ('Fl', 'ORG'),
#   ('In Grave', 'PER'): ('In Grave', 'PER'),
#   ('Amnesty', 'ORG'): ('Amnesty', 'ORG'),
#   ('Centre for', 'ORG'): ('Centre for', 'ORG'),
#   ('Replacement title', 'ORG'): ('Replacement title', 'ORG'),
#   ('Centrumpartij', 'ORG'): ('Centrumpartij', 'ORG'),
#   ('Charles de Gaulle', 'PER'): ('Charles de Gaulle', 'PER'),
#   ('Daniel Gros', 'PER'): ('Daniel Gros', 'PER'),
#   ('Ministerraad', 'ORG'): ('Ministerraad', 'ORG'),
#   ('W.K. Hoekzema', 'PER'): ('W.K.Hoekzema', 'PER'),
#   ('Europese volksvertegenwoordigers',
#    'ORG'): ('Europese volksvertegenwoordigers', 'ORG'),
#   ('Teun', 'PER'): ('Teun', 'PER'),
#   ('Euromunt', 'ORG'): ('Euromunt', 'ORG'),
#   ('Bureau voor de Grondrechten', 'ORG'): ('Bureau voor de Grondrechten',
#    'ORG'),
#   ('Kupchan', 'PER'): ('Kupchan', 'PER'),
#   ('Ubels', 'ORG'): ('Ubels', 'ORG'),
#   ('Groen Progressief', 'ORG'): ('Groen Progressief', 'ORG'),
#   ('Tony Blair', 'PER'): ('Tony Blair', 'PER'),
#   ('Stimulering van', 'ORG'): ('Stimulering van', 'ORG'),
#   ('Heleen de Bruijn', 'PER'): ('Heleen de Bruijn', 'PER'),
#   ('Ben van der Velden', 'PER'): ('Ben van der Velden', 'PER'),
#   ('Saddam Hussein', 'PER'): ('Saddam Hussein', 'PER'),
#   ('Marcelino Oreja', 'PER'): ('Marcelino Oreja', 'PER'),
#   ('Mandelson', 'PER'): ('Mandelson', 'PER'),
#   ('Rousseau', 'PER'): ('Rousseau', 'PER'),
#   ('van Fischer', 'PER'): ('Fischer', 'PER'),
#   ('I', 'PER'): ('I', 'PER'),
#   ('EU-commissaris Franco', 'PER'): ('EU-commissaris Franco', 'PER'),
#   ('Veiligheid en Samenwerking', 'ORG'): ('Veiligheid en Samenwerking', 'ORG'),
#   ('AAA', 'ORG'): ('NONE', None),
#   ('Holbrooke', 'PER'): ('Holbrooke', 'PER'),
#   ('Centrale', 'ORG'): ('Centrale', 'ORG'),
#   ('Charles Dickens', 'PER'): ('Charles Dickens', 'PER'),
#   ('John Ramaker', 'PER'): ('John Ramaker', 'PER'),
#   ('De la', 'PER'): ('De la', 'PER'),
#   ('Santer', 'ORG'): ('Santer', 'ORG'),
#   ('Unie voor de buitenwacht vele gezichten',
#    'ORG'): ('Unie voor de buitenwacht vele gezichten', 'ORG'),
#   ('Joegoslavië', 'ORG'): ('Joegoslavie', 'ORG'),
#   ('Nicolaï', 'PER'): ('Nicolai', 'PER'),
#   ('Tom Eijsbouts', 'PER'): ('Tom Eijsbouts', 'PER'),
#   ('Europese Raad-president Van Rompuy',
#    'ORG'): ('Europese Raad-president Van Rompuy', 'ORG'),
#   ('Berger', 'ORG'): ('Berger', 'ORG'),
#   ('Vrije Universiteit', 'ORG'): ('Vrije Universiteit', 'ORG'),
#   ('Peter de Graaf', 'PER'): ('Peter de Graaf', 'PER'),
#   ('Europese Agentschap voor Visserijcontrole',
#    'ORG'): ('Europese Agentschap voor Visserijcontrole', 'ORG'),
#   ('Nederlands Instituut voor Oecologisch Onderzoek',
#    'ORG'): ('Nederlands Instituut voor Oecologisch Onderzoek', 'ORG'),
#   ('Haughey', 'PER'): ('Haughey', 'PER'),
#   ('Chirac', 'PER'): ('Chirac', 'PER'),
#   ('Wonen', 'ORG'): ('Wonen', 'ORG'),
#   ('Winston Churchill', 'PER'): ('Winston Churchill', 'PER'),
#   ('José Manuel Barroso', 'PER'): ('Jose Manuel Barroso', 'PER'),
#   ('Lissabonverdrag', 'ORG'): ('Lissabonverdrag', 'ORG'),
#   ('Economische Monetaire Unie', 'ORG'): ('Economische Monetaire Unie', 'ORG'),
#   ('Centraal Planbureau', 'ORG'): ('Centraal Planbureau', 'ORG'),
#   ('KFOR', 'ORG'): ('KFOR', 'ORG'),
#   ('Europese Hof van Justitie', 'ORG'): ('Europese Hof van Justitie', 'ORG'),
#   ('Herman', 'PER'): ('Herman', 'PER'),
#   ('Pauline Dekker en Wanda de Kanter',
#    'PER'): ('Pauline Dekker en Wanda de Kanter', 'PER'),
#   ('EMI', 'ORG'): ('EMI', 'ORG'),
#   ('Türk', 'PER'): ('Turk', 'PER'),
#   ('EU', 'ORG'): ('EU', 'ORG'),
#   ('A. van Staden', 'PER'): ('A.van Staden', 'PER'),
#   ('Institute', 'ORG'): ('Institute', 'ORG'),
#   ('Dini', 'PER'): ('Dini', 'PER'),
#   ('Europees Parlement', 'ORG'): ('Europees Parlement', 'ORG'),
#   ('Martijn van Dam', 'PER'): ('Martijn van Dam', 'PER'),
#   ('aldus Robertson', 'PER'): ('Robertson', 'PER'),
#   ('Paavo Lipponen', 'PER'): ('Paavo Lipponen', 'PER'),
#   ('Stabilisatie- en Associatieovereenkomst',
#    'ORG'): ('Stabilisatie-en Associatieovereenkomst', 'ORG'),
#   ('stelde Byrne', 'PER'): ('Byrne', 'PER'),
#   ('De Villepin', 'PER'): ('De Villepin', 'PER'),
#   ('Koninklijke', 'ORG'): ('Koninklijke', 'ORG'),
#   ('Clerides', 'PER'): ('Clerides', 'PER'),
#   ('A. Geelhoed', 'PER'): ('A.Geelhoed', 'PER'),
#   ('Patten', 'PER'): ('Patten', 'PER'),
#   ('Unice', 'PER'): ('Unice', 'PER'),
#   ('in Grave', 'PER'): ('Grave', 'PER'),
#   ('Wolven', 'ORG'): ('Wolven', 'ORG'),
#   ('Zarko Puhovski', 'PER'): ('Zarko Puhovski', 'PER'),
#   ('?', 'PER'): ('NONE', None),
#   ('Michael Gove', 'PER'): ('Michael Gove', 'PER'),
#   ('liet Andriessen', 'PER'): ('Andriessen', 'PER'),
#   ('Universiteit Maastricht', 'ORG'): ('Universiteit Maastricht', 'ORG'),
#   ('Willem de Ruijter', 'PER'): ('Willem de Ruijter', 'PER'),
#   ('GroenLinks', 'ORG'): ('GroenLinks', 'ORG'),
#   (' Hol', 'PER'): ('Hol', 'PER'),
#   ('Rompuy', 'PER'): ('Rompuy', 'PER'),
#   ('Charlie Flanagan', 'PER'): ('Charlie Flanagan', 'PER'),
#   ('Simons', 'PER'): ('Simons', 'PER'),
#   ('Publieke', 'ORG'): ('Publieke', 'ORG'),
#   ('Hansch', 'PER'): ('Hansch', 'PER'),
#   ('VVD', 'ORG'): ('VVD', 'ORG'),
#   ('Vanhanen', 'PER'): ('Vanhanen', 'PER'),
#   ('Claudio Gaudiosi', 'PER'): ('Claudio Gaudiosi', 'PER'),
#   ('Unie voor Nederland', 'ORG'): ('Unie voor Nederland', 'ORG'),
#   ('Aldo Ajello', 'PER'): ('Aldo Ajello', 'PER'),
#   ('Instituut Nobel', 'ORG'): ('Instituut Nobel', 'ORG'),
#   ('Unie-gemiddelde', 'ORG'): ('Unie-gemiddelde', 'ORG'),
#   ('Bert Schampers', 'PER'): ('Bert Schampers', 'PER'),
#   ('Thierry Baudet', 'PER'): ('Thierry Baudet', 'PER'),
#   ('Leonoor Kuijk', 'PER'): ('Leonoor Kuijk', 'PER'),
#   ('Bot', 'PER'): ('Bot', 'PER'),
#   ('Godett', 'PER'): ('Godett', 'PER'),
#   ('Brian Cowen', 'PER'): ('Brian Cowen', 'PER'),
#   ('Romano Prodi', 'PER'): ('Romano Prodi', 'PER'),
#   ('Wijers', 'PER'): ('Wijers', 'PER'),
#   ('Eijffinger', 'PER'): ('Eijffinger', 'PER'),
#   ('Algirdas Eáemeta', 'ORG'): ('Algirdas Eaemeta', 'ORG'),
#   ('DARKO VOJINOVIC', 'PER'): ('DARKO VOJINOVIC', 'PER'),
#   ('Samaranch', 'PER'): ('Samaranch', 'PER'),
#   ('Jose Barroso', 'PER'): ('Jose Barroso', 'PER'),
#   ('Jelke Bethlehem', 'PER'): ('Jelke Bethlehem', 'PER'),
#   ('Bankenunie', 'ORG'): ('Bankenunie', 'ORG'),
#   ('BBC', 'ORG'): ('BBC', 'ORG'),
#   ('ODS', 'ORG'): ('ODS', 'ORG'),
#   ('Wiebenga', 'PER'): ('Wiebenga', 'PER'),
#   ('Beurs van', 'ORG'): ('Beurs van', 'ORG'),
#   ('Ankie Broekers-Knol', 'PER'): ('Ankie Broekers-Knol', 'PER'),
#   ('Negende Symfonie', 'ORG'): ('Negende Symfonie', 'ORG'),
#   ('Instituut Clingendael', 'ORG'): ('Instituut Clingendael', 'ORG'),
#   ('Esther Bijlo', 'PER'): ('Esther Bijlo', 'PER'),
#   ('Louis Michel', 'PER'): ('Louis Michel', 'PER'),
#   ('Jan Henry Olsen', 'PER'): ('Jan Henry Olsen', 'PER'),
#   ('Hashim Thaci', 'PER'): ('Hashim Thaci', 'PER'),
#   ('EPG', 'ORG'): ('EPG', 'ORG'),
#   ('Geert Wilders', 'PER'): ('Geert Wilders', 'PER'),
#   ('EEG', 'ORG'): ('EEG', 'ORG'),
#   ('Hetty van Rooij', 'PER'): ('Hetty van Rooij', 'PER'),
#   ('Rehns', 'PER'): ('Rehns', 'PER'),
#   ('Icesafe', 'PER'): ('Icesafe', 'PER'),
#   ('EFSA', 'ORG'): ('EFSA', 'ORG'),
#   ('Gemeenschap', 'ORG'): ('Gemeenschap', 'ORG'),
#   ('Benjamin', 'PER'): ('Benjamin', 'PER'),
#   ('Joop Meijnen', 'PER'): ('Joop Meijnen', 'PER'),
#   ('terwijl Major', 'PER'): ('Major', 'PER'),
#   ('Bronislaw Geremek', 'PER'): ('Bronislaw Geremek', 'PER'),
#   ('Ritva Koukku-Ronde', 'PER'): ('Ritva Koukku-Ronde', 'PER'),
#   ('J.A. Hoeksma', 'PER'): ('J.A.Hoeksma', 'PER'),
#   ('AFP', 'ORG'): ('NONE', None),
#   ('CSM sloot', 'ORG'): ('CSM sloot', 'ORG'),
#   ('Eerste', 'ORG'): ('Eerste', 'ORG'),
#   ('Renè van der Linden', 'PER'): ('Rene van der Linden', 'PER'),
#   ('Europese Economische en Monetaire Unie',
#    'ORG'): ('Europese Economische en Monetaire Unie', 'ORG'),
#   ('EGKS', 'ORG'): ('EGKS', 'ORG'),
#   ('Jacques Santer', 'PER'): ('Jacques Santer', 'PER'),
#   ('Javier Solona', 'PER'): ('Javier Solona', 'PER'),
#   ('Krajisnik', 'PER'): ('Krajisnik', 'PER'),
#   ('er Blom', 'PER'): ('Blom', 'PER'),
#   ('Europese Monetaire', 'ORG'): ('Europese Monetaire', 'ORG'),
#   ('Radboud Universiteit Nijmegen', 'ORG'): ('Radboud Universiteit Nijmegen',
#    'ORG'),
#   ('Henri Kissinger', 'PER'): ('Henri Kissinger', 'PER'),
#   ('CSM Suiker', 'ORG'): ('CSM Suiker', 'ORG'),
#   ('Jose Maria Aznar', 'PER'): ('Jose Maria Aznar', 'PER'),
#   ('Humanitaire Aangelegenheden', 'ORG'): ('Humanitaire Aangelegenheden',
#    'ORG'),
#   ('Openbare', 'ORG'): ('Openbare', 'ORG'),
#   ('Corbyn', 'PER'): ('Corbyn', 'PER'),
#   ('Clinton', 'PER'): ('Clinton', 'PER'),
#   ('Cem', 'PER'): ('Cem', 'PER'),
#   ('Georges Iacovou', 'PER'): ('Georges Iacovou', 'PER'),
#   ('minister Bossi', 'PER'): ('Bossi', 'PER'),
#   ('De Visser', 'PER'): ('De Visser', 'PER'),
#   ('EUObserver', 'ORG'): ('EUObserver', 'ORG'),
#   ('Fréderic Allemand', 'PER'): ('Frederic Allemand', 'PER'),
#   ('AS', 'ORG'): ('AS', 'ORG'),
#   ('Macrons', 'PER'): ('Macrons', 'PER'),
#   ('Microsoft', 'ORG'): ('Microsoft', 'ORG'),
#   ('Uitdaging', 'ORG'): ('Uitdaging', 'ORG'),
#   ('Chizhov', 'PER'): ('Chizhov', 'PER'),
#   ('Euro-voorzitter Chirac', 'PER'): ('Euro-voorzitter Chirac', 'PER'),
#   ('Europarlementarier', 'ORG'): ('Europarlementarier', 'ORG'),
#   ('André Szász', 'PER'): ('Andre Szasz', 'PER'),
#   ('Euro', 'ORG'): ('Euro', 'ORG'),
#   ('Donis Chrostophinis', 'PER'): ('Donis Chrostophinis', 'PER'),
#   ('Volgens Fischer', 'PER'): ('Volgens Fischer', 'PER'),
#   ('heeft May', 'PER'): ('May', 'PER'),
#   ('Jaap de Hoop Scheffer', 'PER'): ('Jaap de Hoop Scheffer', 'PER'),
#   ('Jan Kojak', 'PER'): ('Jan Kojak', 'PER'),
#   ('Osama Bin Laden', 'PER'): ('Osama Bin Laden', 'PER'),
#   ('Kwasniewski', 'PER'): ('Kwasniewski', 'PER'),
#   ('aldus Straw', 'PER'): ('Straw', 'PER'),
#   (', Vincent Mentzel', 'PER'): ('Vincent Mentzel', 'PER'),
#   ('Tommaso Padoa-Schioppa', 'PER'): ('Tommaso Padoa-Schioppa', 'PER'),
#   ('Liberaal Democraten', 'ORG'): ('Liberaal Democraten', 'ORG'),
#   ('Jefferson', 'PER'): ('Jefferson', 'PER'),
#   ('Presidents', 'PER'): ('Presidents', 'PER'),
#   ('Chris Patten', 'PER'): ('Chris Patten', 'PER'),
#   ('dat May', 'PER'): ('May', 'PER'),
#   ('Frans Timmermans', 'PER'): ('Frans Timmermans', 'PER'),
#   ('De Nigel', 'PER'): ('De Nigel', 'PER'),
#   ('tussen May en Trump', 'PER'): ('May en Trump', 'PER'),
#   ('Durieux', 'PER'): ('Durieux', 'PER'),
#   ('Karl-Theodor zu Guttenberg', 'PER'): ('Karl-Theodor zu Guttenberg', 'PER'),
#   ('Verheugen', 'PER'): ('Verheugen', 'PER'),
#   ('Kulturele Haadstêd', 'ORG'): ('Kulturele Haadsted', 'ORG'),
#   ('Jean-Pierre Raffarin', 'PER'): ('Jean-Pierre Raffarin', 'PER'),
#   ('Eurofer', 'ORG'): ('Eurofer', 'ORG'),
#   ('Sophany Ramaen', 'ORG'): ('Sophany Ramaen', 'ORG'),
#   ('Bosnisch Servische republiek', 'ORG'): ('Bosnisch Servische republiek',
#    'ORG'),
#   ('Europese Parlement', 'ORG'): ('Europese Parlement', 'ORG'),
#   ('Leon Brittan', 'PER'): ('Leon Brittan', 'PER'),
#   ('Djukanovic', 'ORG'): ('Djukanovic', 'ORG'),
#   ('Vladimir Boekovski', 'PER'): ('Vladimir Boekovski', 'PER'),
#   ('Giuliano Amato', 'PER'): ('Giuliano Amato', 'PER'),
#   ('Mark Rutte', 'PER'): ('Mark Rutte', 'PER'),
#   ('BONN', 'ORG'): ('BONN', 'ORG'),
#   ('Boekovski', 'PER'): ('Boekovski', 'PER'),
#   ('Manuel Marin', 'PER'): ('Manuel Marin', 'PER'),
#   ('Carlos Westendorp', 'PER'): ('Carlos Westendorp', 'PER'),
#   ('Ciller', 'ORG'): ('Ciller', 'ORG'),
#   ('Saint Louis', 'ORG'): ('Saint Louis', 'ORG'),
#   ('Stan Simons', 'PER'): ('Stan Simons', 'PER'),
#   ('Svejk', 'PER'): ('Svejk', 'PER'),
#   ('toekomstige Monetaire Unie', 'ORG'): ('Monetaire Unie', 'ORG'),
#   ('Marcel Proust', 'PER'): ('Marcel Proust', 'PER'),
#   ('Sadiq Khan', 'PER'): ('Sadiq Khan', 'PER'),
#   ('Blair', 'PER'): ('Blair', 'PER'),
#   ('Speech May', 'PER'): ('Speech May', 'PER'),
#   ('Jack Straw', 'PER'): ('Jack Straw', 'PER'),
#   ('Villepin', 'PER'): ('Villepin', 'PER'),
#   ('Ken Sara-Wiwa', 'PER'): ('Ken Sara-Wiwa', 'PER'),
#   ('Lufthansa', 'ORG'): ('Lufthansa', 'ORG'),
#   ('Barroso Rutte', 'PER'): ('Barroso Rutte', 'PER'),
#   ('DUITSE BIJVAL VOOR CHIRAC', 'ORG'): ('DUITSE BIJVAL VOOR CHIRAC', 'ORG'),
#   ('SVP', 'ORG'): ('SVP', 'ORG'),
#   ('Jan Peter', 'PER'): ('Jan Peter', 'PER'),
#   ('Salmond', 'PER'): ('Salmond', 'PER'),
#   ('SNP', 'ORG'): ('SNP', 'ORG'),
#   ('Kees de Jager', 'PER'): ('Kees de Jager', 'PER'),
#   ('Amsterdam', 'ORG'): ('Amsterdam', 'ORG'),
#   ('LAMBERT VAN NISTELROOIJ', 'PER'): ('LAMBERT VAN NISTELROOIJ', 'PER'),
#   ('ETS', 'ORG'): ('ETS', 'ORG'),
#   ('Studies', 'ORG'): ('Studies', 'ORG'),
#   ('Chiracs', 'PER'): ('Chiracs', 'PER'),
#   ('Donald Trump', 'PER'): ('Donald Trump', 'PER'),
#   ('Riccardo Petrella', 'PER'): ('Riccardo Petrella', 'PER'),
#   ('Federica Mogherini', 'PER'): ('Federica Mogherini', 'PER'),
#   ('Bush', 'PER'): ('Bush', 'PER'),
#   ('zaken Nguyen Manh Cam', 'PER'): ('Nguyen Manh Cam', 'PER'),
#   ('Formentor', 'PER'): ('Formentor', 'PER'),
#   ('Thorvald Stoltenberg', 'PER'): ('Thorvald Stoltenberg', 'PER'),
#   ('Nationale Partij', 'ORG'): ('Nationale Partij', 'ORG'),
#   ('Porsche', 'ORG'): ('Porsche', 'ORG'),
#   ('Pg', 'PER'): ('Pg', 'PER'),
#   ('Cius', 'PER'): ('Cius', 'PER'),
#   ('Iacovou', 'PER'): ('Iacovou', 'PER'),
#   ('Union pour la Méditerranée', 'ORG'): ('Union pour la Mediterranee', 'ORG'),
#   ('City', 'ORG'): ('City', 'ORG'),
#   ('Jaroslav Hasek', 'PER'): ('Jaroslav Hasek', 'PER'),
#   ('Alexander', 'PER'): ('Alexander', 'PER'),
#   ('Internationale', 'ORG'): ('Internationale', 'ORG'),
#   ('Alleingang', 'ORG'): ('Alleingang', 'ORG'),
#   ('Wim Kok', 'PER'): ('Wim Kok', 'PER'),
#   ('Picnic', 'PER'): ('Picnic', 'PER'),
#   ('Rosenmoller', 'ORG'): ('Rosenmoller', 'ORG'),
#   ('Václav Klaus', 'PER'): ('Vaclav Klaus', 'PER'),
#   ('Europese Commissie', 'ORG'): ('Europese Commissie', 'ORG'),
#   ('minister Wijers', 'PER'): ('Wijers', 'PER'),
#   ('Eurojust', 'ORG'): ('Eurojust', 'ORG'),
#   ('Ruurd Ubels', 'PER'): ('Ruurd Ubels', 'PER'),
#   ('Raad', 'ORG'): ('Raad', 'ORG'),
#   ('Bob van den Bos', 'PER'): ('Bob van den Bos', 'PER'),
#   ('En Temps', 'ORG'): ('En Temps', 'ORG'),
#   ('Jozias van Aartsen', 'PER'): ('Jozias van Aartsen', 'PER'),
#   ('Major', 'PER'): ('Major', 'PER'),
#   ('Cameron begin', 'PER'): ('Cameron begin', 'PER'),
#   ('Viktor Janoekovitsj', 'PER'): ('Viktor Janoekovitsj', 'PER'),
#   ('Minsk', 'PER'): ('Minsk', 'PER'),
#   ('Technische Wetenschappen', 'ORG'): ('Technische Wetenschappen', 'ORG'),
#   ('Rampen', 'PER'): ('Rampen', 'PER'),
#   ('Gemeenschappen', 'ORG'): ('Gemeenschappen', 'ORG'),
#   ('Janusz Lewandowski', 'PER'): ('Janusz Lewandowski', 'PER'),
#   ('Nederlandse Europarlementarier Maij-Weggen',
#    'ORG'): ('Nederlandse Europarlementarier Maij-Weggen', 'ORG'),
#   ('verwees Erdogan', 'PER'): ('Erdogan', 'PER'),
#   ('zei Wallström', 'PER'): ('Wallstrom', 'PER'),
#   ('Juncker', 'PER'): ('Juncker', 'PER'),
#   ('Valentin Vogt', 'PER'): ('Valentin Vogt', 'PER'),
#   ('Janvier Solana', 'PER'): ('Janvier Solana', 'PER'),
#   ('Boris Johnson', 'PER'): ('Boris Johnson', 'PER'),
#   ('Europese Beweging Internationaal',
#    'ORG'): ('Europese Beweging Internationaal', 'ORG'),
#   ('European Reform', 'ORG'): ('European Reform', 'ORG'),
#   ('Willem Reijn', 'PER'): ('Willem Reijn', 'PER'),
#   ('Bouteflika', 'PER'): ('Bouteflika', 'PER'),
#   ('Navo', 'ORG'): ('Navo', 'ORG'),
#   ('Hendrik Jan', 'PER'): ('Hendrik Jan', 'PER'),
#   ('Cosgrove', 'PER'): ('Cosgrove', 'PER'),
#   ('Europees Hof voor de', 'ORG'): ('Europees Hof voor de', 'ORG'),
#   ('Roel Kuipers', 'PER'): ('Roel Kuipers', 'PER'),
#   ('Hans-Gert Pottering', 'PER'): ('Hans-Gert Pottering', 'PER'),
#   ('Zwitserse Volkspartij', 'ORG'): ('Zwitserse Volkspartij', 'ORG'),
#   ('Nicole', 'PER'): ('Nicole', 'PER'),
#   ('PvdA', 'ORG'): ('PvdA', 'ORG'),
#   ('Tusk', 'PER'): ('Tusk', 'PER'),
#   ('Mayors', 'PER'): ('Mayors', 'PER'),
#   ('Van Miert', 'PER'): ('Van Miert', 'PER'),
#   ('achter Felipe', 'PER'): ('Felipe', 'PER'),
#   ('Landbouwminister Van Aartsen', 'PER'): ('Landbouwminister Van Aartsen',
#    'PER'),
#   ('Nassim Nicholas Taleb', 'PER'): ('Nassim Nicholas Taleb', 'PER'),
#   ('Nel van Dijk', 'PER'): ('Nel van Dijk', 'PER'),
#   ('Eurofer', 'PER'): ('Eurofer', 'PER'),
#   ('Unie jegens Turkije', 'ORG'): ('Unie jegens Turkije', 'ORG'),
#   ('Milosovic', 'PER'): ('Milosovic', 'PER'),
#   ('Antonio Gutierrez', 'PER'): ('Antonio Gutierrez', 'PER'),
#   ('Jean-Claude Trichet', 'PER'): ('Jean-Claude Trichet', 'PER'),
#   ('Europees Referendum', 'ORG'): ('Europees Referendum', 'ORG'),
#   ('Nelson Mandela', 'PER'): ('Nelson Mandela', 'PER'),
#   ('ATHENE', 'ORG'): ('ATHENE', 'ORG'),
#   ('WHO', 'ORG'): ('WHO', 'ORG'),
#   ('Richard Holbrooke', 'PER'): ('Richard Holbrooke', 'PER'),
#   ('Hendrik Jan ten Cate', 'PER'): ('Hendrik Jan ten Cate', 'PER'),
#   ('A. van Hoof', 'PER'): ('A.van Hoof', 'PER'),
#   ('Katinka Barysch', 'PER'): ('Katinka Barysch', 'PER'),
#   ('met Delors', 'PER'): ('Delors', 'PER'),
#   ('Maxime Verhagen', 'PER'): ('Maxime Verhagen', 'PER'),
#   ('Rijkswaterstaat', 'ORG'): ('Rijkswaterstaat', 'ORG'),
#   ('Markusse', 'PER'): ('Markusse', 'PER'),
#   ('Olli Rehn', 'PER'): ('Olli Rehn', 'PER'),
#   ('Griekenlands', 'PER'): ('Griekenlands', 'PER'),
#   ('Eberhard Bort', 'PER'): ('Eberhard Bort', 'PER'),
#   ('Taalkunde', 'ORG'): ('Taalkunde', 'ORG'),
#   ('Nick Cosgrove', 'PER'): ('Nick Cosgrove', 'PER'),
#   ('Joegoslavie', 'ORG'): ('Joegoslavie', 'ORG'),
#   ('Europese Commissie Santer', 'ORG'): ('Europese Commissie Santer', 'ORG'),
#   ('Staalgemeenschap', 'PER'): ('Staalgemeenschap', 'PER'),
#   ('Securities', 'ORG'): ('Securities', 'ORG'),
#   ('Dijkstra', 'PER'): ('Dijkstra', 'PER'),
#   ('Europees Parlement Volksvertegenwoordiging',
#    'ORG'): ('Europees Parlement Volksvertegenwoordiging', 'ORG'),
#   ('Gerard Meussen', 'PER'): ('Gerard Meussen', 'PER'),
#   ('Jan Peter Balkenende', 'PER'): ('Jan Peter Balkenende', 'PER'),
#   ('ECB', 'ORG'): ('ECB', 'ORG'),
#   ('Smith', 'PER'): ('Smith', 'PER'),
#   ('Maral', 'PER'): ('Maral', 'PER'),
#   ('G. Sikken', 'PER'): ('G.Sikken', 'PER'),
#   ('Ante Gotovina', 'PER'): ('Ante Gotovina', 'PER'),
#   ('Labourregering', 'ORG'): ('Labourregering', 'ORG'),
#   ('Socrates', 'PER'): ('Socrates', 'PER'),
#   ('God', 'PER'): ('God', 'PER'),
#   ('Vlaams Blok', 'ORG'): ('Vlaams Blok', 'ORG'),
#   ('Raoul Leerling', 'PER'): ('Raoul Leerling', 'PER'),
#   ('Economische en Monetarie Unie', 'ORG'): ('Economische en Monetarie Unie',
#    'ORG'),
#   ('Europese Gemeenschap voor Atoomenergie',
#    'ORG'): ('Europese Gemeenschap voor Atoomenergie', 'ORG'),
#   ('Wereldbank', 'ORG'): ('Wereldbank', 'ORG'),
#   ('PvdA-Statenlid Van Kollem', 'PER'): ('PvdA-Statenlid Van Kollem', 'PER'),
#   ('Groupe de Reflexion', 'ORG'): ('Groupe de Reflexion', 'ORG'),
#   ('Joesjtsjenko', 'PER'): ('Joesjtsjenko', 'PER'),
#   ('Iacovou', 'ORG'): ('Iacovou', 'ORG'),
#   ('Wolfsen', 'PER'): ('Wolfsen', 'PER'),
#   ('Obama', 'PER'): ('Obama', 'PER'),
#   ('Voorhoeve', 'PER'): ('Voorhoeve', 'PER'),
#   ('Papandreou', 'PER'): ('Papandreou', 'PER'),
#   ('Nicolas de Sadeleer', 'PER'): ('Nicolas de Sadeleer', 'PER'),
#   ('Europese Unie in', 'ORG'): ('Europese Unie in', 'ORG'),
#   ('Leonid Koetsjma', 'PER'): ('Leonid Koetsjma', 'PER'),
#   ('Martino', 'PER'): ('Martino', 'PER'),
#   ('Staat ; Defensie', 'ORG'): ('Staat Defensie', 'ORG'),
#   ('Janoekovitsj', 'PER'): ('Janoekovitsj', 'PER'),
#   ('Ferrero Waldner', 'PER'): ('Ferrero Waldner', 'PER'),
#   ('Jacques Rogge', 'PER'): ('Jacques Rogge', 'PER'),
#   ('Norsk Hydro', 'ORG'): ('Norsk Hydro', 'ORG'),
#   ('Pers', 'ORG'): ('Pers', 'ORG'),
#   ('Straw', 'PER'): ('Straw', 'PER'),
#   ('Rijksvoorlichtingsdienst', 'ORG'): ('Rijksvoorlichtingsdienst', 'ORG'),
#   ('Maarten Engwirda', 'PER'): ('Maarten Engwirda', 'PER'),
#   ('Alain Lamassoure', 'PER'): ('Alain Lamassoure', 'PER'),
#   ('Alex Salmond', 'PER'): ('Alex Salmond', 'PER'),
#   ('minister Rosenthal', 'PER'): ('Rosenthal', 'PER'),
#   ('Koks', 'PER'): ('Koks', 'PER'),
#   ('Poetin', 'PER'): ('Poetin', 'PER'),
#   ('Willibrord van Beek', 'PER'): ('Willibrord van Beek', 'PER'),
#   ('Radek Sikorski', 'PER'): ('Radek Sikorski', 'PER'),
#   ('Juan Antonio Samaranch', 'PER'): ('Juan Antonio Samaranch', 'PER'),
#   ('Kapucijn Karel Verleye', 'PER'): ('Kapucijn Karel Verleye', 'PER'),
#   ('NIOZ', 'ORG'): ('NIOZ', 'ORG'),
#   ('Juncker', 'ORG'): ('Juncker', 'ORG'),
#   ('Jan Willem Jongejans', 'PER'): ('Jan Willem Jongejans', 'PER'),
#   ('Orde', 'ORG'): ('Orde', 'ORG'),
#   ('Conventie', 'ORG'): ('Conventie', 'ORG'),
#   ('Viktor Joesjtsjenko', 'PER'): ('Viktor Joesjtsjenko', 'PER'),
#   ('Groen van Prinsterer Stichting', 'ORG'): ('Groen van Prinsterer Stichting',
#    'ORG'),
#   ('Billboard', 'ORG'): ('Billboard', 'ORG'),
#   ('Confédération Générale des Coopératives Agricoles',
#    'ORG'): ('Confederation Generale des Cooperatives Agricoles', 'ORG'),
#   ('Europese Unie !', 'ORG'): ('Europese Unie ', 'ORG'),
#   ('FPÖ', 'ORG'): ('FPO', 'ORG'),
#   ('Peter Spijker', 'PER'): ('Peter Spijker', 'PER'),
#   ('Schotlands', 'PER'): ('Schotlands', 'PER'),
#   ('SYP WYNIA', 'PER'): ('SYP WYNIA', 'PER'),
#   ('Geert-Jan Bogaerts', 'PER'): ('Geert-Jan Bogaerts', 'PER'),
#   ('Commissie als Europees Parlement',
#    'ORG'): ('Commissie als Europees Parlement', 'ORG'),
#   ('Europese Commissie Uitvoerende', 'ORG'): ('Europese Commissie Uitvoerende',
#    'ORG'),
#   ('Ona Jukneviciene', 'PER'): ('Ona Jukneviciene', 'PER'),
#   ('Helmut Kohl', 'PER'): ('Helmut Kohl', 'PER'),
#   ('Kazimír', 'PER'): ('Kazimir', 'PER'),
#   ('Staat van de Unie', 'ORG'): ('Staat van de Unie', 'ORG'),
#   ('Radetzkymars', 'PER'): ('Radetzkymars', 'PER'),
#   ('Europese Hof van Justitie Europol',
#    'ORG'): ('Europese Hof van Justitie Europol', 'ORG'),
#   ('Ton Hesp', 'PER'): ('Ton Hesp', 'PER'),
#   ('Duin', 'PER'): ('Duin', 'PER'),
#   ('Hetty van Rooy', 'PER'): ('Hetty van Rooy', 'PER'),
#   ('Het gebruik van colistine', 'ORG'): ('Het gebruik van colistine', 'ORG'),
#   ('An Ocean of', 'PER'): ('An Ocean of', 'PER'),
#   ('Wouter Bos', 'PER'): ('Wouter Bos', 'PER'),
#   ('Brammertz', 'PER'): ('Brammertz', 'PER'),
#   ('Josè Manuel Barroso', 'PER'): ('Jose Manuel Barroso', 'PER'),
#   ('Podgorica', 'PER'): ('Podgorica', 'PER'),
#   ('Maarten Vink', 'PER'): ('Maarten Vink', 'PER'),
#   ('MAASTRICHT', 'ORG'): ('MAASTRICHT', 'ORG'),
#   ('Jan Willem Bertens', 'PER'): ('Jan Willem Bertens', 'PER'),
#   ('Bill Clinton', 'PER'): ('Bill Clinton', 'PER'),
#   ('Europaeam Unionem', 'PER'): ('Europaeam Unionem', 'PER'),
#   ('Rik Kamps', 'PER'): ('Rik Kamps', 'PER'),
#   ('Republikeinen', 'ORG'): ('Republikeinen', 'ORG'),
#   ('NAVO', 'ORG'): ('NAVO', 'ORG'),
#   ('Cyprioten VN-plan', 'PER'): ('Cyprioten VN-plan', 'PER'),
#   ('Schröder', 'PER'): ('Schroder', 'PER'),
#   ('Pandora', 'ORG'): ('Pandora', 'ORG'),
#   ('Pedro Solbes', 'PER'): ('Pedro Solbes', 'PER'),
#   ('Bert Doorn', 'PER'): ('Bert Doorn', 'PER'),
#   ('ABN AMRO', 'ORG'): ('NONE', None),
#   ('Sikken', 'PER'): ('Sikken', 'PER'),
#   ('Lucebert', 'PER'): ('Lucebert', 'PER'),
#   ('Van Dam', 'PER'): ('Van Dam', 'PER'),
#   ('Bort', 'PER'): ('Bort', 'PER'),
#   ('Aveyron', 'ORG'): ('Aveyron', 'ORG'),
#   ('Schout', 'PER'): ('Schout', 'PER'),
#   ('Europolverdrag', 'ORG'): ('Europolverdrag', 'ORG'),
#   ('Richard Corbett', 'PER'): ('Richard Corbett', 'PER'),
#   ('Organisatie voor Veiligheid en Samenwerking',
#    'ORG'): ('Organisatie voor Veiligheid en Samenwerking', 'ORG'),
#   ('Vucic', 'PER'): ('Vucic', 'PER'),
#   ('DEC', 'ORG'): ('DEC', 'ORG'),
#   ('Davis', 'PER'): ('Davis', 'PER'),
#   ('Center', 'ORG'): ('Center', 'ORG'),
#   ('Alva', 'PER'): ('Alva', 'PER'),
#   ('Andriessen', 'PER'): ('Andriessen', 'PER'),
#   ('Staatsrecht ; Regering', 'ORG'): ('Staatsrecht Regering', 'ORG'),
#   ('Fressen', 'PER'): ('Fressen', 'PER'),
#   ('De Gaulle', 'PER'): ('De Gaulle', 'PER'),
#   ('Christa Tobler', 'PER'): ('Christa Tobler', 'PER'),
#   ('Hassan', 'PER'): ('Hassan', 'PER'),
#   ('Duisenberg', 'PER'): ('Duisenberg', 'PER'),
#   ('Zuercher', 'PER'): ('Zuercher', 'PER'),
#   ('Hans Bos', 'PER'): ('Hans Bos', 'PER'),
#   ('belastingrecht Radboud Universiteit Nijmegen',
#    'ORG'): ('Radboud Universiteit Nijmegen', 'ORG'),
#   ('Reiter', 'PER'): ('Reiter', 'PER'),
#   ('Michel Barnier', 'PER'): ('Michel Barnier', 'PER'),
#   ('Sali Berisha', 'PER'): ('Sali Berisha', 'PER'),
#   ('Permanent Veterinair Comité', 'ORG'): ('Permanent Veterinair Comite',
#    'ORG'),
#   ('Eerste Kamer', 'ORG'): ('Eerste Kamer', 'ORG'),
#   ('Rasmussen', 'PER'): ('Rasmussen', 'PER'),
#   ('Albert Markusse', 'PER'): ('Albert Markusse', 'PER'),
#   ('wat Fischer', 'PER'): ('Fischer', 'PER'),
#   ('Vereniging van Europese', 'ORG'): ('Vereniging van Europese', 'ORG'),
#   ('REUTERS', 'ORG'): ('REUTERS', 'ORG'),
#   ('Völner', 'PER'): ('Volner', 'PER'),
#   ('Hoger', 'ORG'): ('Hoger', 'ORG'),
#   ('Tobias Stoll', 'PER'): ('Tobias Stoll', 'PER'),
#   ('Milo Djukanovic', 'PER'): ('Milo Djukanovic', 'PER'),
#   ('Jo Bonfrere', 'PER'): ('Jo Bonfrere', 'PER'),
#   ('David Cameron', 'PER'): ('David Cameron', 'PER'),
#   ('Deryckes', 'PER'): ('Deryckes', 'PER'),
#   ('Johnson &', 'ORG'): ('Johnson ', 'ORG'),
#   ('Günter Verheugen', 'PER'): ('Gunter Verheugen', 'PER'),
#   ('Green', 'ORG'): ('Green', 'ORG'),
#   ('Congres', 'ORG'): ('Congres', 'ORG'),
#   ('Socialistische Partij', 'ORG'): ('Socialistische Partij', 'ORG'),
#   ('NOV', 'ORG'): ('NOV', 'ORG'),
#   ('Gerard Lyons', 'PER'): ('Gerard Lyons', 'PER'),
#   ('Ismail Cem', 'PER'): ('Ismail Cem', 'PER'),
#   ('Fillon', 'PER'): ('Fillon', 'PER'),
#   ('Saddam Husseins', 'PER'): ('Saddam Husseins', 'PER'),
#   ('Joegoslavië-Tribunaal', 'ORG'): ('Joegoslavie-Tribunaal', 'ORG'),
#   ('aldus Delors', 'PER'): ('Delors', 'PER'),
#   ('Europees Monetair', 'ORG'): ('Europees Monetair', 'ORG'),
#   ('Scharping', 'PER'): ('Scharping', 'PER'),
#   ('Van Brummelen', 'PER'): ('Van Brummelen', 'PER'),
#   ('Reviuslyceum', 'ORG'): ('Reviuslyceum', 'ORG'),
#   ('Lucht- en Ruimtevaartrecht', 'ORG'): ('Lucht-en Ruimtevaartrecht', 'ORG'),
#   ('Azur', 'PER'): ('Azur', 'PER'),
#   ('Jan-Kees Wiebenga', 'PER'): ('Jan-Kees Wiebenga', 'PER'),
#   ('Europol', 'PER'): ('Europol', 'PER'),
#   ('Luxemburgers', 'PER'): ('Luxemburgers', 'PER'),
#   ('volgens Bolkestein', 'PER'): ('Bolkestein', 'PER'),
#   ('Leonard Orban', 'PER'): ('Leonard Orban', 'PER'),
#   ('Blz', 'ORG'): ('Blz', 'ORG'),
#   ('Rode Kruis', 'ORG'): ('Rode Kruis', 'ORG'),
#   ('Carl Bildt', 'PER'): ('Carl Bildt', 'PER'),
#   ('Parlement', 'ORG'): ('Parlement', 'ORG'),
#   ('Hitler', 'PER'): ('Hitler', 'PER'),
#   ('Air', 'ORG'): ('Air', 'ORG'),
#   ('Marijn van Klingeren', 'PER'): ('Marijn van Klingeren', 'PER'),
#   ('Europarlementariers', 'PER'): ('Europarlementariers', 'PER'),
#   ('Benschops', 'PER'): ('Benschops', 'PER'),
#   ('Evcevit', 'PER'): ('Evcevit', 'PER'),
#   ('Solbes', 'PER'): ('Solbes', 'PER'),
#   ('Umit Enginsoy', 'PER'): ('Umit Enginsoy', 'PER'),
#   ('Rhodos', 'PER'): ('Rhodos', 'PER'),
#   ('Klestil', 'PER'): ('Klestil', 'PER'),
#   ('Joris Voorhoeve', 'PER'): ('Joris Voorhoeve', 'PER'),
#   ('Luigi Corrias', 'PER'): ('Luigi Corrias', 'PER'),
#   ('premier Major', 'PER'): ('Major', 'PER'),
#   ('Westerwelle', 'ORG'): ('Westerwelle', 'ORG'),
#   ('van der Vaart', 'PER'): ('der Vaart', 'PER'),
#   ('ANP / BART MAAT', 'ORG'): ('ANP BART MAAT', 'ORG'),
#   ('Van Middelkoop', 'PER'): ('Van Middelkoop', 'PER'),
#   ('W. van Gelder', 'PER'): ('W.van Gelder', 'PER'),
#   ('Blairs', 'PER'): ('Blairs', 'PER'),
#   ('James Hill', 'PER'): ('James Hill', 'PER'),
#   ('DeStem', 'ORG'): ('DeStem', 'ORG'),
#   ('Peter Bielars', 'PER'): ('Peter Bielars', 'PER'),
#   ('Macron', 'PER'): ('Macron', 'PER'),
#   ('premier Jospin', 'PER'): ('Jospin', 'PER'),
#   ('David Owen', 'PER'): ('David Owen', 'PER'),
#   ('VVD-CDA', 'ORG'): ('VVD-CDA', 'ORG'),
#   ('Sowjet Unie', 'ORG'): ('Sowjet Unie', 'ORG'),
#   ('IMF', 'ORG'): ('IMF', 'ORG'),
#   ('Etihad', 'PER'): ('Etihad', 'PER'),
#   ('Nederland 3', 'ORG'): ('Nederland ', 'ORG'),
#   ('Léon Cornelissen', 'PER'): ('Leon Cornelissen', 'PER'),
#   ('Erik Derycke', 'PER'): ('Erik Derycke', 'PER'),
#   ('Corbett', 'PER'): ('Corbett', 'PER'),
#   ('Browne', 'PER'): ('Browne', 'PER'),
#   ('Ton Monasso', 'PER'): ('Ton Monasso', 'PER'),
#   ('Jan', 'PER'): ('Jan', 'PER'),
#   ('Drnovsek van Slovenie', 'PER'): ('Drnovsek van Slovenie', 'PER'),
#   ('J.H. Sampiemon', 'PER'): ('J.H.Sampiemon', 'PER'),
#   ('Byrne', 'PER'): ('Byrne', 'PER'),
#   ('Nederlands Vaccin Instituut', 'ORG'): ('Nederlands Vaccin Instituut',
#    'ORG'),
#   ('Staat van de Unie van', 'ORG'): ('Staat van de Unie van', 'ORG'),
#   ('Sociaal Comite', 'ORG'): ('Sociaal Comite', 'ORG'),
#   ('Verzekeringswezen', 'ORG'): ('Verzekeringswezen', 'ORG'),
#   ('Jos Klaassen', 'PER'): ('Jos Klaassen', 'PER'),
#   ('J.W. Sap', 'PER'): ('J.W.Sap', 'PER'),
#   ('Dierenleed', 'ORG'): ('Dierenleed', 'ORG'),
#   ('Mogherini', 'PER'): ('Mogherini', 'PER'),
#   ('Antonio Vitorino', 'PER'): ('Antonio Vitorino', 'PER'),
#   ('Simonetta Sommaruga', 'PER'): ('Simonetta Sommaruga', 'PER'),
#   ('Europese Comité', 'ORG'): ('Europese Comite', 'ORG'),
#   ('Ilves', 'PER'): ('Ilves', 'PER'),
#   ('Kostunica', 'PER'): ('Kostunica', 'PER'),
#   ('Dick Roche', 'PER'): ('Dick Roche', 'PER'),
#   ('Economische unie', 'ORG'): ('Economische unie', 'ORG'),
#   ('Eurocracy', 'ORG'): ('Eurocracy', 'ORG'),
#   ('Ron Magne  e', 'PER'): ('Ron Magne e', 'PER'),
#   ('Europese Unie van Conventie-voorzitter',
#    'ORG'): ('Europese Unie van Conventie-voorzitter', 'ORG'),
#   ('Karimi', 'PER'): ('Karimi', 'PER'),
#   ('De Brauw Blackstone Westbroek', 'ORG'): ('De Brauw Blackstone Westbroek',
#    'ORG'),
#   ('Reuters', 'ORG'): ('Reuters', 'ORG'),
#   ('Schauble', 'PER'): ('Schauble', 'PER'),
#   ('Aegon', 'ORG'): ('Aegon', 'ORG'),
#   ('KPN', 'ORG'): ('KPN', 'ORG'),
#   ('PLO', 'ORG'): ('PLO', 'ORG'),
#   ('Steven van Hoogstraten', 'PER'): ('Steven van Hoogstraten', 'PER'),
#   ('Vigo', 'ORG'): ('Vigo', 'ORG'),
#   ('Landelijk', 'ORG'): ('Landelijk', 'ORG'),
#   ('J.M.F. Waterreus', 'PER'): ('J.M.F.Waterreus', 'PER'),
#   ('beleid Trump', 'PER'): ('Trump', 'PER'),
#   ('Union', 'ORG'): ('Union', 'ORG'),
#   ('AA', 'ORG'): ('NONE', None),
#   ('JOOST VAN EGMOND', 'PER'): ('JOOST VAN EGMOND', 'PER'),
#   ('Mustafa Oguz Demiralp', 'ORG'): ('Mustafa Oguz Demiralp', 'ORG'),
#   ('Reiters', 'PER'): ('Reiters', 'PER'),
#   ('AA+', 'ORG'): ('NONE', None),
#   ('Topolaneks Democratische Burgerpartij',
#    'ORG'): ('Topolaneks Democratische Burgerpartij', 'ORG'),
#   ('Yanis Varoufakis', 'PER'): ('Yanis Varoufakis', 'PER'),
#   ('Hof van Justitie', 'ORG'): ('Hof van Justitie', 'ORG'),
#   ('Hans van Meerten', 'PER'): ('Hans van Meerten', 'PER'),
#   ('Unie Anders Fogh Rasmussen', 'ORG'): ('Unie Anders Fogh Rasmussen', 'ORG'),
#   ('Joop Hartog', 'PER'): ('Joop Hartog', 'PER'),
#   ('Huis ter', 'ORG'): ('Huis ter', 'ORG'),
#   ('Rik Winkel', 'PER'): ('Rik Winkel', 'PER'),
#   ('Otto Holman', 'PER'): ('Otto Holman', 'PER'),
#   ('Innovation Politique', 'ORG'): ('Innovation Politique', 'ORG'),
#   ('Peter Kazimír', 'PER'): ('Peter Kazimir', 'PER'),
#   ('E.P. Wellenstein', 'ORG'): ('E.P.Wellenstein', 'ORG'),
#   ('Sociaal', 'ORG'): ('Sociaal', 'ORG'),
#   ('Merkels', 'PER'): ('Merkels', 'PER'),
#   ('Claude Juncker', 'PER'): ('Claude Juncker', 'PER'),
#   ('Leonard Orbanm', 'PER'): ('Leonard Orbanm', 'PER'),
#   ('VdM', 'ORG'): ('VdM', 'ORG'),
#   ('Servie', 'PER'): ('Servie', 'PER'),
#   ('Robin Cook', 'PER'): ('Robin Cook', 'PER'),
#   ('Verhofstadt', 'PER'): ('Verhofstadt', 'PER'),
#   ('AP Onur Oymen', 'ORG'): ('AP Onur Oymen', 'ORG'),
#   ('Skadden Arps', 'PER'): ('Skadden Arps', 'PER'),
#   ('H. van den Broek', 'PER'): ('H.van den Broek', 'PER'),
#   ('J.', 'PER'): ('J.', 'PER'),
#   ('Independence Party', 'ORG'): ('Independence Party', 'ORG'),
#   ('G-7', 'ORG'): ('G-', 'ORG'),
#   ('Sigrid de Vries', 'PER'): ('Sigrid de Vries', 'PER'),
#   ('Hamas', 'ORG'): ('Hamas', 'ORG'),
#   ('Utrechtsch Studenten Corps', 'ORG'): ('Utrechtsch Studenten Corps', 'ORG'),
#   ('VOORZITTERSCHAP VAN', 'PER'): ('VOORZITTERSCHAP VAN', 'PER'),
#   ('Groot', 'ORG'): ('Groot', 'ORG'),
#   ('Waigel', 'ORG'): ('Waigel', 'ORG'),
#   ('Arjen van der', 'PER'): ('Arjen van der', 'PER'),
#   ('Erich Reiter', 'PER'): ('Erich Reiter', 'PER'),
#   ('toen Bolkestein', 'PER'): ('Bolkestein', 'PER'),
#   ('Overheidsfinancien', 'ORG'): ('Overheidsfinancien', 'ORG'),
#   ('Mohammed', 'PER'): ('Mohammed', 'PER'),
#   ('Leon', 'PER'): ('Leon', 'PER'),
#   ('ECU', 'ORG'): ('ECU', 'ORG'),
#   ('Jan Maat', 'PER'): ('Jan Maat', 'PER'),
#   ('Ormel', 'PER'): ('Ormel', 'PER'),
#   ('Goran Persson', 'PER'): ('Goran Persson', 'PER'),
#   ('Josep Borrell', 'PER'): ('Josep Borrell', 'PER'),
#   ('Lambert van Nistelrooij', 'PER'): ('Lambert van Nistelrooij', 'PER'),
#   ('Andreotti', 'PER'): ('Andreotti', 'PER'),
#   ('vzw Ryckevelde', 'ORG'): ('Ryckevelde', 'ORG'),
#   ('M. van Rossem', 'PER'): ('M.van Rossem', 'PER'),
#   ('John van Miltenburg', 'PER'): ('John van Miltenburg', 'PER'),
#   ('zei Bolkestein', 'PER'): ('Bolkestein', 'PER'),
#   ('Kissinger', 'PER'): ('Kissinger', 'PER'),
#   ('en Monetaire Unie', 'ORG'): ('Monetaire Unie', 'ORG'),
#   ('Organisatie voor Economische Samenwerking en Ontwikkeling',
#    'ORG'): ('Organisatie voor Economische Samenwerking en Ontwikkeling',
#    'ORG'),
#   ('zonder Grenzen', 'ORG'): ('Grenzen', 'ORG'),
#   ('Ilkin', 'ORG'): ('Ilkin', 'ORG'),
#   ('S.E. de Vries', 'PER'): ('S.E.de Vries', 'PER'),
#   ('PAG', 'ORG'): ('PAG', 'ORG'),
#   ('Carnegie Stichting', 'ORG'): ('Carnegie Stichting', 'ORG'),
#   ('Peter Ramsauer', 'PER'): ('Peter Ramsauer', 'PER'),
#   ('J.Th. Degenkamp', 'PER'): ('J.Th.Degenkamp', 'PER'),
#   ('ING', 'ORG'): ('ING', 'ORG'),
#   ('Staatsrecht', 'ORG'): ('Staatsrecht', 'ORG'),
#   ('Hetty van Rooij Strategisch', 'PER'): ('Hetty van Rooij Strategisch',
#    'PER'),
#   ('Wendelin Wiedeking', 'PER'): ('Wendelin Wiedeking', 'PER'),
#   ('Kinkel', 'PER'): ('Kinkel', 'PER'),
#   ('Keulen', 'PER'): ('Keulen', 'PER'),
#   ('CO', 'ORG'): ('CO', 'ORG'),
#   ('Europese Investeringsbank', 'ORG'): ('Europese Investeringsbank', 'ORG'),
#   ('DOUBLE_QUOTE Federalisme', 'ORG'): ('DOUBLE_QUOTE Federalisme', 'ORG'),
#   ('JEROEN Kuiper', 'PER'): ('JEROEN Kuiper', 'PER'),
#   ('Van Baalen', 'PER'): ('Van Baalen', 'PER'),
#   ('Estlands', 'PER'): ('Estlands', 'PER'),
#   ('Europees Monetair Instituut', 'ORG'): ('Europees Monetair Instituut',
#    'ORG'),
#   ('Samsom', 'PER'): ('Samsom', 'PER'),
#   ('Herman Dooyeweerd', 'PER'): ('Herman Dooyeweerd', 'PER'),
#   ('premier May', 'PER'): ('May', 'PER'),
#   ('Pablo Mendes', 'PER'): ('Pablo Mendes', 'PER'),
#   ('Meulenhoff', 'ORG'): ('Meulenhoff', 'ORG'),
#   ('Dato Steenhuis', 'PER'): ('Dato Steenhuis', 'PER'),
#   ('Euratom', 'ORG'): ('Euratom', 'ORG'),
#   ('International Herald Tribune', 'ORG'): ('International Herald Tribune',
#    'ORG'),
#   ('Orbán', 'PER'): ('Orban', 'PER'),
#   ('NATIONAAL', 'ORG'): ('NATIONAAL', 'ORG'),
#   ('Europese Unie de Europese grondwet .',
#    'ORG'): ('Europese Unie de Europese grondwet ', 'ORG'),
#   ('Davidson', 'PER'): ('Davidson', 'PER'),
#   ('Goran Hadzic', 'PER'): ('Goran Hadzic', 'PER'),
#   ('Europese Economische Ruimte', 'ORG'): ('Europese Economische Ruimte',
#    'ORG'),
#   ('PL', 'ORG'): ('PL', 'ORG'),
#   ('Beethoven', 'PER'): ('Beethoven', 'PER'),
#   ('Cosun', 'PER'): ('Cosun', 'PER'),
#   ('Export', 'ORG'): ('Export', 'ORG'),
#   ('socialist Gonzalez', 'PER'): ('Gonzalez', 'PER'),
#   ('Thorbjørn Jagland', 'PER'): ('Thorbjorn Jagland', 'PER'),
#   ('Lamberto Dini', 'PER'): ('Lamberto Dini', 'PER'),
#   ('Universiteit', 'ORG'): ('Universiteit', 'ORG'),
#   ('Centrum', 'ORG'): ('Centrum', 'ORG'),
#   ('Emine Bozkurt', 'PER'): ('Emine Bozkurt', 'PER'),
#   ('Jasper Boon', 'PER'): ('Jasper Boon', 'PER'),
#   ('Europe', 'ORG'): ('Europe', 'ORG'),
#   ('CSM', 'ORG'): ('CSM', 'ORG'),
#   ('Justus Lipsius-gebouw', 'PER'): ('Justus Lipsius-gebouw', 'PER'),
#   ('Burgers', 'ORG'): ('Burgers', 'ORG'),
#   ('AD', 'ORG'): ('NONE', None),
#   ('van Adenauer en Schmidt', 'PER'): ('Adenauer en Schmidt', 'PER'),
#   ('Organisatie van Afrikaanse Eenheid',
#    'ORG'): ('Organisatie van Afrikaanse Eenheid', 'ORG'),
#   ('British', 'ORG'): ('British', 'ORG'),
#   ('Europarlementarier Wiebenga', 'PER'): ('Europarlementarier Wiebenga',
#    'PER'),
#   ('Algemene Vergadering', 'ORG'): ('Algemene Vergadering', 'ORG'),
#   ('plaats Felipe Gonzalez', 'PER'): ('Felipe Gonzalez', 'PER'),
#   ('Renault', 'PER'): ('Renault', 'PER'),
#   ('Handelsblatt', 'PER'): ('Handelsblatt', 'PER'),
#   ('Bernard de Montferrand', 'PER'): ('Bernard de Montferrand', 'PER'),
#   ('Unie', 'ORG'): ('Unie', 'ORG'),
#   ('Westeuropese Unie', 'ORG'): ('Westeuropese Unie', 'ORG'),
#   ('In', 'ORG'): ('In', 'ORG'),
#   ('Ferdinand Cheval', 'PER'): ('Ferdinand Cheval', 'PER'),
#   ('HDZ', 'ORG'): ('HDZ', 'ORG'),
#   ('Integratie van de WEU', 'ORG'): ('Integratie van de WEU', 'ORG'),
#   ('Innovatiecentrum Veenkoloniën', 'ORG'): ('Innovatiecentrum Veenkolonien',
#    'ORG'),
#   ('Schotten', 'ORG'): ('Schotten', 'ORG'),
#   ('vzw', 'ORG'): ('vzw', 'ORG'),
#   ('Raad van Europa waarnemers naar',
#    'ORG'): ('Raad van Europa waarnemers naar', 'ORG'),
#   ('Centraal Bureau voor de Statistiek',
#    'ORG'): ('Centraal Bureau voor de Statistiek', 'ORG'),
#   ('Ali Babacan', 'PER'): ('Ali Babacan', 'PER'),
#   ('Europese Conventie', 'ORG'): ('Europese Conventie', 'ORG'),
#   ('George Robertson', 'PER'): ('George Robertson', 'PER'),
#   ('Welvaartspartij', 'ORG'): ('Welvaartspartij', 'ORG'),
#   ('Francois', 'PER'): ('Francois', 'PER'),
#   ('Aznar', 'PER'): ('Aznar', 'PER'),
#   ('Delors', 'PER'): ('Delors', 'PER'),
#   ('Johnson', 'PER'): ('Johnson', 'PER'),
#   ('Politico', 'PER'): ('Politico', 'PER'),
#   ('Rehn', 'ORG'): ('Rehn', 'ORG'),
#   ('Kreizberg', 'PER'): ('Kreizberg', 'PER'),
#   ('Hans Hoogervorst', 'PER'): ('Hans Hoogervorst', 'PER'),
#   ('Tietmeyer', 'PER'): ('Tietmeyer', 'PER'),
#   ('Cetin', 'PER'): ('Cetin', 'PER'),
#   ('Frits Mueller', 'PER'): ('Frits Mueller', 'PER'),
#   ('Adam Smith', 'PER'): ('Adam Smith', 'PER'),
#   ('Vladimir Spidla', 'PER'): ('Vladimir Spidla', 'PER'),
#   ('I.', 'PER'): ('I.', 'PER'),
#   ('Kantinka Barysch', 'PER'): ('Kantinka Barysch', 'PER'),
#   ('Plavsic', 'PER'): ('Plavsic', 'PER'),
#   ('Gonzalez', 'PER'): ('Gonzalez', 'PER'),
#   ('bracht Straw', 'PER'): ('Straw', 'PER'),
#   ('José Barroso', 'PER'): ('Jose Barroso', 'PER'),
#   ('Van Rompuy', 'ORG'): ('Van Rompuy', 'ORG'),
#   ('Dalia Grybauskaite', 'PER'): ('Dalia Grybauskaite', 'PER'),
#   ('Luchtvaartmaatschappij Air', 'ORG'): ('Luchtvaartmaatschappij Air', 'ORG'),
#   ('BDO Belastingadviseurs', 'ORG'): ('BDO Belastingadviseurs', 'ORG'),
#   ('HANS HEIJT', 'PER'): ('HANS HEIJT', 'PER'),
#   ('Wen Jeabao', 'PER'): ('Wen Jeabao', 'PER'),
#   ('De Grauwe', 'PER'): ('De Grauwe', 'PER'),
#   ('Harrie van der Meulen', 'PER'): ('Harrie van der Meulen', 'PER'),
#   ('conservatief-nationalistische Partij voor Recht en Gerechtigheid',
#    'ORG'): ('conservatief-nationalistische Partij voor Recht en Gerechtigheid',
#    'ORG'),
#   ('Ilkin', 'PER'): ('Ilkin', 'PER'),
#   ('EMSA', 'ORG'): ('EMSA', 'ORG'),
#   ('Europese Unie 21 officiële werktalen',
#    'ORG'): ('Europese Unie officiele werktalen', 'ORG'),
#   ('Bertens', 'PER'): ('Bertens', 'PER'),
#   ('HIGHLIGHT', 'ORG'): ('HIGHLIGHT', 'ORG'),
#   ('Staatsrecht', 'PER'): ('Staatsrecht', 'PER'),
#   ('Danilo Türk', 'PER'): ('Danilo Turk', 'PER'),
#   ('KNCV', 'ORG'): ('KNCV', 'ORG'),
#   ('EMU', 'ORG'): ('EMU', 'ORG'),
#   ('Candido Mendez', 'PER'): ('Candido Mendez', 'PER'),
#   ('Poltieke Unie', 'ORG'): ('Poltieke Unie', 'ORG'),
#   ('Micropolis', 'ORG'): ('Micropolis', 'ORG'),
#   ('Porosjenko', 'PER'): ('Porosjenko', 'PER'),
#   ('Foodwatch', 'PER'): ('Foodwatch', 'PER'),
#   ('Wolfgang Schäuble', 'PER'): ('Wolfgang Schauble', 'PER'),
#   ('Cees Oudshoorn', 'PER'): ('Cees Oudshoorn', 'PER'),
#   ('Carla del Ponte', 'PER'): ('Carla del Ponte', 'PER'),
#   ('Topconferenties ; Buitenlandse betrekkingen',
#    'ORG'): ('Topconferenties Buitenlandse betrekkingen', 'ORG'),
#   ('Mladic', 'PER'): ('Mladic', 'PER'),
#   ('Wereldhandelsorganisatie', 'ORG'): ('Wereldhandelsorganisatie', 'ORG'),
#   ('URSS', 'ORG'): ('URSS', 'ORG'),
#   ('Unie in Brussel', 'ORG'): ('Unie in Brussel', 'ORG'),
#   ('Raad van Economische Organisaties',
#    'ORG'): ('Raad van Economische Organisaties', 'ORG'),
#   ('Wallström', 'PER'): ('Wallstrom', 'PER'),
#   ('Wolfgang Schauble', 'PER'): ('Wolfgang Schauble', 'PER'),
#   ('Jan Jacob van Dijk', 'PER'): ('Jan Jacob van Dijk', 'PER'),
#   ('Marthe van der Wolf Meer', 'PER'): ('Marthe van der Wolf Meer', 'PER'),
#   ('Rutte', 'PER'): ('Rutte', 'PER'),
#   ('BASF', 'ORG'): ('BASF', 'ORG'),
#   ('Ahmed Korei', 'PER'): ('Ahmed Korei', 'PER'),
#   ('Aleksander Kwasniewski', 'PER'): ('Aleksander Kwasniewski', 'PER'),
#   ('Bloomberg', 'ORG'): ('Bloomberg', 'ORG'),
#   ('Alfred Pijpers', 'PER'): ('Alfred Pijpers', 'PER'),
#   ('Cosun', 'ORG'): ('Cosun', 'ORG'),
#   ('Holman', 'PER'): ('Holman', 'PER'),
#   ('Silvio Berlusconi', 'PER'): ('Silvio Berlusconi', 'PER'),
#   ('Kofi Annan', 'PER'): ('Kofi Annan', 'PER'),
#   ('Glafkos Clerides', 'PER'): ('Glafkos Clerides', 'PER'),
#   ('Miklos TOth', 'PER'): ('Miklos TOth', 'PER'),
#   ('Maurits Sep', 'PER'): ('Maurits Sep', 'PER'),
#   ('Wilders', 'PER'): ('Wilders', 'PER'),
#   ('Andreas Papandreou', 'PER'): ('Andreas Papandreou', 'PER'),
#   ('CEATL', 'ORG'): ('CEATL', 'ORG'),
#   ('Centrale Banken', 'ORG'): ('Centrale Banken', 'ORG'),
#   ('Sander Luitwieler', 'PER'): ('Sander Luitwieler', 'PER'),
#   ('Peter', 'PER'): ('Peter', 'PER'),
#   ('Dirk Hekking', 'PER'): ('Dirk Hekking', 'PER'),
#   ('KGB-spion Alexander Litvinenko', 'PER'): ('KGB-spion Alexander Litvinenko',
#    'PER'),
#   ('Europese Unie Rusland', 'ORG'): ('Europese Unie Rusland', 'ORG'),
#   ('met Felipe', 'PER'): ('Felipe', 'PER'),
#   ('Cees', 'PER'): ('Cees', 'PER'),
#   ('Barnier', 'PER'): ('Barnier', 'PER'),
#   ('De', 'ORG'): ('De', 'ORG'),
#   ('IGC96', 'ORG'): ('IGC9', 'ORG'),
#   ('Raad van Beheer van Cosun', 'ORG'): ('Raad van Beheer van Cosun', 'ORG'),
#   ('Levey', 'PER'): ('Levey', 'PER'),
#   ('Phil Hogan', 'PER'): ('Phil Hogan', 'PER'),
#   ('Vladimir Poetin', 'PER'): ('Vladimir Poetin', 'PER'),
#   ('Jean-Claude Juncker', 'PER'): ('Jean-Claude Juncker', 'PER'),
#   ('Henry Schermers', 'PER'): ('Henry Schermers', 'PER'),
#   ('Mehmet Ali Talat', 'PER'): ('Mehmet Ali Talat', 'PER'),
#   ('Felipe Gonzalez', 'PER'): ('Felipe Gonzalez', 'PER'),
#   ('Simitis', 'PER'): ('Simitis', 'PER'),
#   ('Wolters', 'PER'): ('Wolters', 'PER'),
#   ('Diederik Samsom', 'PER'): ('Diederik Samsom', 'PER'),
#   ('Death', 'PER'): ('Death', 'PER'),
#   ('De Mooij', 'PER'): ('De Mooij', 'PER'),
#   ('NV', 'ORG'): ('NV', 'ORG'),
#   ('Europese Unie van', 'ORG'): ('Europese Unie van', 'ORG'),
#   ('Schotten', 'PER'): ('Schotten', 'PER'),
#   ('Vojislav Kostunica', 'PER'): ('Vojislav Kostunica', 'PER'),
#   ('Publiek', 'ORG'): ('Publiek', 'ORG'),
#   ('Vaclav Klaus', 'PER'): ('Vaclav Klaus', 'PER'),
#   ('Jet Bussemaker', 'PER'): ('Jet Bussemaker', 'PER'),
#   ('Lega Nord', 'ORG'): ('Lega Nord', 'ORG'),
#   ('Instituut Nyenrode', 'ORG'): ('Instituut Nyenrode', 'ORG'),
#   ('Steenbergen', 'PER'): ('Steenbergen', 'PER'),
#   ('BBC Trust', 'ORG'): ('BBC Trust', 'ORG'),
#   ('Zaire', 'ORG'): ('Zaire', 'ORG'),
#   ('Frattini', 'PER'): ('Frattini', 'PER'),
#   ('Georgié', 'PER'): ('Georgie', 'PER'),
#   ('MARCEL VAN', 'PER'): ('MARCEL VAN', 'PER'),
#   ('Europese Unie Anders', 'ORG'): ('Europese Unie Anders', 'ORG'),
#   ('Dijsselbloem', 'PER'): ('Dijsselbloem', 'PER'),
#   ('Ruth Davidson', 'PER'): ('Ruth Davidson', 'PER'),
#   ('Geremek', 'PER'): ('Geremek', 'PER'),
#   ('Felix Pons', 'PER'): ('Felix Pons', 'PER'),
#   ('Yasser Arafat', 'PER'): ('Yasser Arafat', 'PER'),
#   ('NVI', 'ORG'): ('NVI', 'ORG'),
#   ('Europadag', 'ORG'): ('Europadag', 'ORG'),
#   ('Cypriotische Federatie', 'ORG'): ('Cypriotische Federatie', 'ORG'),
#   ('R.A. Wessel', 'PER'): ('R.A.Wessel', 'PER'),
#   ('Tomislav Nikolic', 'PER'): ('Tomislav Nikolic', 'PER'),
#   ('Iñigo Mendez', 'PER'): ('Inigo Mendez', 'PER'),
#   ('R.A. de Mooij', 'PER'): ('R.A.de Mooij', 'PER'),
#   ('José Zapatero', 'PER'): ('Jose Zapatero', 'PER'),
#   ('Jean Asselborn', 'PER'): ('Jean Asselborn', 'PER'),
#   ('Comite', 'PER'): ('Comite', 'PER'),
#   ('Paul de Grauwe', 'PER'): ('Paul de Grauwe', 'PER'),
#   ('Irma', 'PER'): ('Irma', 'PER'),
#   ('Leymah Roberta Gbowee', 'PER'): ('Leymah Roberta Gbowee', 'PER'),
#   ('Mitterrand', 'PER'): ('Mitterrand', 'PER'),
#   ('Opec', 'ORG'): ('Opec', 'ORG'),
#   ('Olli Rehn over Kostunica', 'PER'): ('Olli Rehn over Kostunica', 'PER'),
#   ('Charles De Gaulle', 'PER'): ('Charles De Gaulle', 'PER'),
#   ('Roel Rozenburg', 'PER'): ('Roel Rozenburg', 'PER'),
#   ('Faull', 'PER'): ('Faull', 'PER'),
#   ('Andreas Papendreou', 'PER'): ('Andreas Papendreou', 'PER'),
#   ('Duda', 'PER'): ('Duda', 'PER'),
#   ('Capital Economics', 'ORG'): ('Capital Economics', 'ORG'),
#   ('EIB', 'ORG'): ('EIB', 'ORG'),
#   ('Ben Bot', 'PER'): ('Ben Bot', 'PER'),
#   ('Economische en Monetaire Unie', 'ORG'): ('Economische en Monetaire Unie',
#    'ORG'),
#   ('Brok', 'PER'): ('Brok', 'PER'),
#   ('JAN', 'ORG'): ('JAN', 'ORG'),
#   ('Martin van Driel', 'PER'): ('Martin van Driel', 'PER'),
#   ('Karla Peijs', 'PER'): ('Karla Peijs', 'PER'),
#   ('Laurent-Desire Kabila', 'PER'): ('Laurent-Desire Kabila', 'PER'),
#   ('Foreign Office', 'ORG'): ('Foreign Office', 'ORG'),
#   ('Stichting Polderhuis', 'ORG'): ('Stichting Polderhuis', 'ORG'),
#   ('Anthony Godett', 'PER'): ('Anthony Godett', 'PER'),
#   ('Cefic', 'PER'): ('Cefic', 'PER'),
#   ('Comité', 'ORG'): ('Comite', 'ORG'),
#   ('Lagerhuis', 'ORG'): ('Lagerhuis', 'ORG'),
#   ('Ramses A. Wessel', 'PER'): ('Ramses A.Wessel', 'PER'),
#   ('Frederik Bergstrom', 'PER'): ('Frederik Bergstrom', 'PER'),
#   ('Centrale Bank Vormt', 'ORG'): ('Centrale Bank Vormt', 'ORG'),
#   ('Martin Schulz', 'PER'): ('Martin Schulz', 'PER'),
#   ('Boris Jeltsin', 'PER'): ('Boris Jeltsin', 'PER'),
#   ('Europese Monetaire Unie', 'ORG'): ('Europese Monetaire Unie', 'ORG'),
#   ('FLIP FRANSSEN', 'PER'): ('FLIP FRANSSEN', 'PER'),
#   ('Gerhard Schröder', 'PER'): ('Gerhard Schroder', 'PER'),
#   ('Europese Unie dinsdag', 'ORG'): ('Europese Unie dinsdag', 'ORG'),
# ...
#   ('Europarlementarier', 'ORG'),
#   ('Europarlementarier Wiebenga', 'PER'),
#   ('Europarlementariers', 'PER'),
#   ('Europe', 'ORG'),
#   ('Europe Calling', 'ORG'),
#   ('Europe Calling-conferentie vrijdag', 'ORG'),
#   ('European', 'ORG'),
#   ('European Centre of Policy Studies', 'ORG'),
#   ('European Reform', 'ORG'),
#   ('Europees', 'ORG'),
#   ('Europees Erfgoedlabel', 'ORG'),
#   ('Europees Garantiefonds', 'ORG'),
#   ('Europees Hof', 'ORG'),
#   ('Europees Hof van Justitie', 'ORG'),
#   ('Europees Hof voor de', 'ORG'),
#   ('Europees Monetair', 'ORG'),
#   ('Europees Monetair Instituut', 'ORG'),
#   ('Europees Parlement', 'ORG'),
#   ('Europees Parlement Volksvertegenwoordiging', 'ORG'),
#   ('Europees Referendum', 'ORG'),
#   ('Europees Waarnemingscentrum', 'ORG'),
#   ('Europees Wisselkoers Mechanisme', 'ORG'),
#   ('Europese', 'ORG'),
#   ('Europese Agentschap voor Visserijcontrole', 'ORG'),
#   ('Europese Bank', 'ORG'),
#   ('Europese Barcelona-proces', 'ORG'),
#   ('Europese Beweging Internationaal', 'ORG'),
#   ('Europese Centrale Bank', 'ORG'),
#   ('Europese Centrale Banken', 'ORG'),
#   ('Europese Comite', 'ORG'),
#   ('Europese Commissie', 'ORG'),
#   ('Europese Commissie Santer', 'ORG'),
#   ('Europese Commissie Uitvoerende', 'ORG'),
#   ('Europese Commissie der Gemeenschap', 'ORG'),
#   ('Europese Commissie van de', 'ORG'),
#   ('Europese Conventie', 'ORG'),
#   ('Europese Defensie Gemeenschap', 'ORG'),
#   ('Europese Defensie Gemeenschap verwierp', 'ORG'),
#   ('Europese Defensie Unie', 'ORG'),
#   ('Europese Economische Gemeenschap', 'ORG'),
#   ('Europese Economische Ruimte', 'ORG'),
#   ('Europese Economische en Monetaire Unie', 'ORG'),
#   ('Europese Gemeenschap', 'ORG'),
#   ('Europese Gemeenschap van Kolen en', 'ORG'),
#   ('Europese Gemeenschap voor Atoomenergie', 'ORG'),
#   ('Europese Gemeenschap voor Kolen en', 'ORG'),
#   ('Europese Gemeenschappen', 'ORG'),
#   ('Europese Hof', 'ORG'),
#   ('Europese Hof van Justitie', 'ORG'),
#   ('Europese Hof van Justitie Europol', 'ORG'),
#   ('Europese Investeringsbank', 'ORG'),
#   ('Europese Ministerraad', 'ORG'),
#   ('Europese Monetaire', 'ORG'),
#   ('Europese Monetaire Instituut', 'ORG'),
#   ('Europese Monetaire Unie', 'ORG'),
#   ('Europese Olympus', 'ORG'),
#   ('Europese Parlement', 'ORG'),
#   ('Europese Raad', 'ORG'),
#   ('Europese Raad Herman van Rompuy', 'ORG'),
#   ('Europese Raad-president Van Rompuy', 'ORG'),
#   ('Europese Rekenkamer', 'ORG'),
#   ('Europese School', 'ORG'),
#   ('Europese Unie', 'ORG'),
#   ('Europese Unie ', 'ORG'),
#   ('Europese Unie Albanie', 'ORG'),
#   ('Europese Unie Anders', 'ORG'),
#   ('Europese Unie Herman', 'ORG'),
#   ('Europese Unie Rusland', 'ORG'),
#   ('Europese Unie Sta', 'ORG'),
#   ('Europese Unie Studies', 'ORG'),
#   ('Europese Unie Turkije', 'ORG'),
#   ('Europese Unie de Europese grondwet ', 'ORG'),
#   ('Europese Unie dinsdag', 'ORG'),
#   ('Europese Unie in', 'ORG'),
#   ('Europese Unie met', 'ORG'),
#   ('Europese Unie officiele werktalen', 'ORG'),
#   ('Europese Unie van', 'ORG'),
#   ('Europese Unie van Conventie-voorzitter', 'ORG'),
#   ('Europese Unie van sentimentele aard', 'ORG'),
#   ('Europese Volkspartij', 'ORG'),
#   ('Europese Vrijhandelsassociatie', 'ORG'),
#   ('Europese unie', 'ORG'),
#   ('Europese volksvertegenwoordigers', 'ORG'),
#   ('Europeser', 'ORG'),
#   ('Europol', 'PER'),
#   ('Europol', 'ORG'),
#   ('Europolverdrag', 'ORG'),
#   ('Eurostat', 'ORG'),
#   ('Eurotop', 'ORG'),
#   ('Eurregio Scheldemond', 'ORG'),
#   ('Evcevit', 'PER'),
#   ('Ewald', 'PER'),
#   ('Export', 'ORG'),
#   ('FBI', 'ORG'),
#   ('FDP', 'ORG'),
#   ('FEBR', 'ORG'),
#   ('FLIP FRANSSEN', 'PER'),
#   ('FNV', 'ORG'),
#   ('FOL', 'ORG'),
#   ('FPO', 'ORG'),
#   ('FT', 'ORG'),
#   ('Faull', 'PER'),
#   ('Federale Uitvoeringsraad', 'ORG'),
#   ('Federica Mogherini', 'PER'),
#   ('Felipe', 'PER'),
#   ('Felipe', 'PER'),
#   ('Felipe Gonzalez', 'PER'),
#   ('Felipe Gonzalez', 'PER'),
#   ('Felix Pons', 'PER'),
#   ('Ferdinand Cheval', 'PER'),
#   ('Ferrero Waldner', 'PER'),
#   ('Fiats', 'PER'),
#   ('Fillon', 'PER'),
#   ('Finlands', 'PER'),
#   ('Fischer', 'PER'),
#   ('Fischer', 'PER'),
#   ('Fischer', 'PER'),
#   ('Fischer', 'PER'),
#   ('Fischer', 'PER'),
#   ('Fischler', 'PER'),
#   ('Fitna', 'PER'),
#   ('Fl', 'ORG'),
#   ('Fondation pour', 'ORG'),
#   ('Fonds', 'ORG'),
#   ('Fontaine', 'ORG'),
#   ('Foodwatch', 'PER'),
#   ('Foreign Office', 'ORG'),
#   ('Formentor', 'PER'),
#   ('FranCois', 'PER'),
#   ('France ', 'ORG'),
#   ('Franco', 'PER'),
#   ('Franco Frattini', 'PER'),
#   ('Francois', 'PER'),
#   ('Frankfort', 'PER'),
#   ('Frankrijk', 'PER'),
#   ('Frans Andriessen', 'PER'),
#   ('Frans Timmermans', 'PER'),
#   ('Franz Fischler', 'PER'),
#   ('Frattini', 'PER'),
#   ('Fred den', 'PER'),
#   ('Frederic Allemand', 'PER'),
#   ('Frederik Bergstrom', 'PER'),
#   ('Fressen', 'PER'),
#   ('Frits Bolkestein', 'PER'),
#   ('Frits Mueller', 'PER'),
#   ('Frits Muller', 'PER'),
#   ('Front National', 'ORG'),
#   ('G-', 'ORG'),
#   ('G.Sikken', 'PER'),
#   ('G.T.K.Meussen', 'PER'),
#   ('GPD', 'ORG'),
#   ('GPD', 'PER'),
#   ('Galileo', 'PER'),
#   ('Gallup', 'ORG'),
#   ('Gazprom', 'ORG'),
#   ('Geert Wilders', 'PER'),
#   ('Geert van Istendael', 'PER'),
#   ('Geert-Jan Bogaerts', 'PER'),
#   ('Geir Lundestad', 'PER'),
#   ('Gemeenschap', 'ORG'),
#   ('Gemeenschappen', 'ORG'),
#   ('Gemeentelijke Gezondheids Diensten', 'ORG'),
#   ('George Bermann', 'PER'),
#   ('George Bush', 'PER'),
#   ('George Robertson', 'PER'),
#   ('George Steiner', 'PER'),
#   ('George W.Bush', 'PER'),
#   ('Georges Iacovou', 'PER'),
#   ('Georgie', 'PER'),
#   ('Gerard Lyons', 'PER'),
#   ('Gerard Meussen', 'PER'),
#   ('Geremek', 'PER'),
#   ('Gerhard Schroder', 'PER'),
#   ('Gerhard Schroder', 'PER'),
#   ('Gerrit Zalm', 'PER'),
#   ('Gijs de Vries', 'PER'),
#   ('Giscard', 'PER'),
#   ('Giscards', 'PER'),
#   ('Giuliano Amato', 'PER'),
#   ('Glafkos Clerides', 'PER'),
#   ('Gligorov', 'PER'),
#   ('God', 'PER'),
#   ('Godett', 'PER'),
#   ('Gonzalez', 'PER'),
#   ('Gonzalez', 'PER'),
#   ('Goran Hadzic', 'PER'),
#   ('Goran Persson', 'PER'),
#   ('Gordon Brown', 'PER'),
#   ('Grave', 'PER'),
#   ('Green', 'ORG'),
#   ('Grenzen', 'ORG'),
#   ('Griekenlands', 'PER'),
#   ('Groen Links', 'ORG'),
#   ('Groen Progressief', 'ORG'),
#   ('Groen van Prinsterer Stichting', 'ORG'),
#   ('GroenLinks', 'ORG'),
#   ('Groninger', 'PER'),
#   ('Groot', 'ORG'),
#   ('Grosser', 'PER'),
#   ('Groupe de Reflexion', 'ORG'),
#   ('Guenter Verheugen', 'PER'),
#   ('Gul', 'PER'),
#   ('Gunter Verheugen', 'PER'),
#   ('Gunter Verheugen', 'PER'),
#   ('Gunther Verheugen', 'PER'),
#   ('Guy Verhofstadt', 'PER'),
#   ('H.Wolters', 'PER'),
#   ('H.van den Broek', 'PER'),
#   ('HANS HEIJT', 'PER'),
#   ('HC', 'PER'),
#   ('HDZ', 'ORG'),
#   ('HFT', 'ORG'),
#   ('HIGHLIGHT', 'ORG'),
#   ('HIGHLIGHT', 'PER'),
#   ('Hadzic', 'PER'),
#   ('Haider', 'PER'),
#   ('Halbe Zijlstra', 'PER'),
#   ('Hamas', 'ORG'),
#   ('Han ten Broeke', 'ORG'),
#   ('Handelsblatt', 'PER'),
#   ('Hanja Maij-Weggen', 'PER'),
#   ('Hans', 'ORG'),
#   ('Hans Bos', 'PER'),
#   ('Hans Gertsen', 'PER'),
#   ('Hans Hoogervorst', 'PER'),
#   ('Hans van Baalen', 'PER'),
#   ('Hans van Meerten', 'PER'),
#   ('Hans van Mierlo', 'PER'),
#   ('Hans van den Broek', 'PER'),
#   ('Hans-Gert Pottering', 'PER'),
#   ('Hansch', 'PER'),
#   ('Harald Mueller', 'PER'),
#   ('Harald von Witzke', 'PER'),
#   ('Harm Koster', 'PER'),
#   ('Harmen Binnema', 'PER'),
#   ('Harrie van der Meulen', 'PER'),
#   ('Hashim Thaci', 'PER'),
#   ('Hassan', 'PER'),
#   ('Haughey', 'PER'),
#   ('Hein de', 'PER'),
#   ('Heinz Fischer', 'PER'),
#   ('Heleen de Bruijn', 'PER'),
#   ('Helmut Kohl', 'PER'),
#   ('Helmut Schmidt', 'PER'),
#   ('Helmut Schmidts', 'PER'),
#   ('Helsingin Sanomat', 'ORG'),
#   ('Hendrik Brugmans', 'PER'),
#   ('Hendrik Jan', 'PER'),
#   ('Hendrik Jan ten Cate', 'PER'),
#   ('Hendrik Jan van Oostrum', 'PER'),
#   ('Henk Kamp', 'PER'),
#   ('Henk van Brummelen', 'PER'),
#   ('Henri Guaino', 'PER'),
#   ('Henri Kissinger', 'PER'),
#   ('Henriette Korner', 'PER'),
#   ('Henry Schermers', 'PER'),
#   ('Herman', 'PER'),
#   ('Herman Dooyeweerd', 'PER'),
#   ('Herman Van Rompuy', 'PER'),
#   ('Het Loo', 'ORG'),
#   ('Het gebruik van colistine', 'ORG'),
#   ('Hetty van Rooij', 'PER'),
#   ('Hetty van Rooij Een', 'PER'),
#   ('Hetty van Rooij Strategisch', 'PER'),
#   ('Hetty van Rooy', 'PER'),
#   ('Hey-De Herder', 'PER'),
#   ('Hezbollah', 'ORG'),
#   ('Hillary Clinton', 'PER'),
#   ('Hitler', 'PER'),
#   ('Hoe May', 'PER'),
#   ('Hof van Justitie', 'ORG'),
#   ('Hoge', 'ORG'),
#   ('Hoger', 'ORG'),
#   ('Hol', 'PER'),
#   ('Holbrooke', 'PER'),
#   ('Holman', 'PER'),
#   ('Homerus', 'PER'),
#   ('Hoogervorst', 'PER'),
#   ('Hoogovens', 'ORG'),
#   ('Horst', 'PER'),
#   ('Howe', 'PER'),
#   ('Hubert Vedrine', 'PER'),
#   ('Huis ter', 'ORG'),
#   ('Human Resource', 'ORG'),
#   ('Humanistische Universiteit', 'ORG'),
#   ('Humanitaire Aangelegenheden', 'ORG'),
#   ('Hurd', 'PER'),
#   ('I', 'PER'),
#   ('I.', 'PER'),
#   ('IFOR', 'ORG'),
#   ('IGC', 'ORG'),
#   ('IGC9', 'ORG'),
#   ('III', 'PER'),
#   ('IMF', 'ORG'),
#   ('ING', 'ORG'),
#   ('IOC', 'ORG'),
#   ('IPTF', 'ORG'),
#   ('Iacovou', 'PER'),
#   ('Iacovou', 'ORG'),
#   ('Icao', 'ORG'),
#   ('Icesafe', 'PER'),
#   ('Ieke van den Burg', 'PER'),
#   ('Ilir Meta', 'PER'),
#   ('Ilkin', 'ORG'),
#   ('Ilkin', 'PER'),
#   ('Ilves', 'PER'),
#   ('In', 'ORG'),
#   ('In Grave', 'PER'),
#   ('Independence Party', 'ORG'),
#   ('Informatica Wetenschap', 'ORG'),
#   ('Inigo Mendez', 'PER'),
#   ('Innovatiecentrum Veenkolonien', 'ORG'),
#   ('Innovation Politique', 'ORG'),
#   ('Institute', 'ORG'),
#   ('Instituut', 'ORG'),
#   ('Instituut Clingendael', 'ORG'),
#   ('Instituut Nobel', 'ORG'),
#   ('Instituut Nyenrode', 'ORG'),
#   ('Integratie van de WEU', 'ORG'),
#   ('Internationaal Monetair Fonds', 'ORG'),
#   ('Internationaal Olympisch Comite', 'ORG'),
#   ('Internationaal Strafhof', 'ORG'),
#   ('International Herald Tribune', 'ORG'),
#   ('Internationale', 'ORG'),
#   ('Internationale Economie', 'ORG'),
#   ('Irma', 'PER'),
#   ('Ismail Cem', 'PER'),
#   ('Ivanov', 'PER'),
#   ('J.', 'PER'),
#   ('J.A.Hoeksma', 'PER'),
#   ('J.A.Hoeksma', 'PER'),
#   ('J.F.Hoogervorst', 'PER'),
#   ('J.H.Sampiemon', 'PER'),
#   ('J.M.F.Waterreus', 'PER'),
#   ('J.Schaberg', 'PER'),
#   ('J.Th.Degenkamp', 'PER'),
#   ('J.Th.Degenkamp', 'PER'),
#   ('J.W.Sap', 'PER'),
#   ('JACCO VAN', 'PER'),
#   ('JAN', 'ORG'),
#   ('JEROEN Kuiper', 'PER'),
#   ('JOOST VAN EGMOND', 'PER'),
#   ('JOVD', 'PER'),
#   ('JOVD', 'ORG'),
#   ('Jaap Hoeksma', 'PER'),
#   ('Jaap W.de Zwaan', 'PER'),
#   ('Jaap de Hoop Scheffer', 'PER'),
#   ('Jack Straw', 'PER'),
#   ('Jack van Ham', 'PER'),
#   ('Jaco van Lambalgen', 'PER'),
#   ('Jacques Calvet', 'PER'),
#   ('Jacques Chirac', 'PER'),
#   ('Jacques Delors', 'PER'),
#   ('Jacques Rogge', 'PER'),
#   ('Jacques Santer', 'PER'),
#   ('Jacques Schraven', 'PER'),
#   ('James Goldsmith', 'PER'),
#   ('James Hill', 'PER'),
#   ('Jamie van', 'PER'),
#   ('Jan', 'PER'),
#   ('Jan Braakman', 'PER'),
#   ('Jan Figel', 'PER'),
#   ('Jan Henry Olsen', 'PER'),
#   ('Jan Hunin', 'PER'),
#   ('Jan Jacob van Dijk', 'PER'),
#   ('Jan Kojak', 'PER'),
#   ('Jan Maat', 'PER'),
#   ('Jan Marinus Wiersma', 'PER'),
#   ('Jan Orbie', 'PER'),
#   ('Jan Peter', 'PER'),
#   ('Jan Peter Balkenende', 'PER'),
#   ('Jan Willem Bertens', 'PER'),
#   ('Jan Willem Jongejans', 'PER'),
#   ('Jan Willem Sap', 'PER'),
#   ('Jan Zanen', 'PER'),
#   ('Jan-Kees Wiebenga', 'PER'),
#   ('Jan-Willem Bertens', 'PER'),
#   ('Janoekovitsj', 'PER'),
#   ('Janus Lewandowski', 'PER'),
#   ('Janusz Kaczurba', 'PER'),
#   ('Janusz Lewandowski', 'PER'),
#   ('Janvier Solana', 'PER'),
#   ('Jaroslav Hasek', 'PER'),
#   ('Jaroslaw Kaczynski', 'PER'),
#   ('Jasper Boon', 'PER'),
#   ('Javier Solana', 'PER'),
#   ('Javier Solona', 'PER'),
#   ('Jazeker', 'ORG'),
#   ('Jean', 'PER'),
#   ('Jean Asselborn', 'PER'),
#   ('Jean Chretien', 'PER'),
#   ('Jean Claude Juncker', 'PER'),
#   ('Jean Monnet', 'PER'),
#   ('Jean-Claude Juncker', 'PER'),
#   ('Jean-Claude Trichet', 'PER'),
#   ('Jean-Henri Fabre', 'PER'),
#   ('Jean-Luc Dehaene', 'PER'),
#   ('Jean-Pierre Raffarin', 'PER'),
#   ('Jeanine Hennis-Plasschaert', 'PER'),
#   ('Jeff Bezos', 'PER'),
#   ('Jefferson', 'PER'),
#   ('Jelke Bethlehem', 'PER'),
#   ('Jeltsin', 'PER'),
#   ('Jeltsin ruggesteun', 'PER'),
#   ('Jenny Kreuk', 'PER'),
#   ('Jens van der', 'PER'),
#   ('Jeremy Corbyn', 'PER'),
#   ('Jeroen Dijsselbloem', 'PER'),
#   ('Jet Bussemaker', 'PER'),
#   ('Jo Bonfrere', 'PER'),
#   ('Joachim Hopperus', 'PER'),
#   ('Joachim Starbatty', 'PER'),
#   ('Joan Muysken', 'PER'),
#   ('Joao Pinheiro', 'PER'),
#   ('Joegoslavie', 'ORG'),
#   ('Joegoslavie', 'ORG'),
#   ('Joegoslavie-Tribunaal', 'ORG'),
#   ('Joegoslavie-tribunaal', 'ORG'),
#   ('Joegoslavietribunaal', 'ORG'),
#   ('Joesjtsjenko', 'PER'),
#   ('Johan Nooitgedagt', 'PER'),
#   ('John Bruton', 'PER'),
#   ('John Geijp', 'PER'),
#   ('John Major', 'PER'),
#   ('John Ramaker', 'PER'),
#   ('John van Miltenburg', 'PER'),
#   ('Johnson', 'PER'),
#   ('Johnson ', 'ORG'),
#   ('Jonathan Gillman', 'PER'),
#   ('Jongs', 'PER'),
#   ('Joop Hartog', 'PER'),
#   ('Joop Meijnen', 'PER'),
#   ('Joost', 'PER'),
#   ('Jorg Haider', 'PER'),
#   ('Joris Voorhoeve', 'PER'),
#   ('Jos Klaassen', 'PER'),
#   ('Joschka Fischer', 'PER'),
#   ('Jose Barroso', 'PER'),
#   ('Jose Barroso', 'PER'),
#   ('Jose Manuel Barroso', 'PER'),
#   ('Jose Manuel Barroso', 'PER'),
#   ('Jose Manuel Barroso', 'PER'),
#   ('Jose Maria Aznar', 'PER'),
#   ('Jose Socrates', 'PER'),
#   ('Jose Zapatero', 'PER'),
#   ('Josep Borrell', 'PER'),
#   ('Joseph Roth', 'PER'),
#   ('Jospin', 'PER'),
#   ('Jozias van Aartsen', 'PER'),
#   ('Juan Antonio Samaranch', 'PER'),
#   ('Jules Maaten', 'PER'),
#   ('Julia Timosjenko', 'PER'),
#   ('Julius Caesar', 'PER'),
#   ('Juncker', 'PER'),
#   ('Juncker', 'ORG'),
#   ('Juppe', 'PER'),
#   ('Justus Lipsius-gebouw', 'PER'),
#   ('KFOR', 'ORG'),
#   ('KGB-spion Alexander Litvinenko', 'PER'),
#   ('KNCV', 'ORG'),
#   ('KNVB', 'ORG'),
#   ('KOK EN', 'ORG'),
#   ('KPN', 'ORG'),
#   ('Kaliningrad', 'PER'),
#   ('Kamer', 'ORG'),
#   ('Kamer van Koophandel', 'ORG'),
#   ('Kamp', 'PER'),
#   ('Kantinka Barysch', 'PER'),
#   ('Kapucijn Karel Verleye', 'PER'),
#   ('Karadzic', 'PER'),
#   ('Karasin', 'PER'),
#   ('Karel De Gucht', 'PER'),
#   ('Karel Verleye', 'PER'),
#   ('Karel de Gucht', 'PER'),
#   ('Karel van Miert', 'PER'),
#   ('Karimi', 'PER'),
#   ('Karin Jusek', 'PER'),
#   ('Karl Lamers', 'PER'),
#   ('Karl-Theodor zu Guttenberg', 'PER'),
#   ('Karla Peijs', 'PER'),
#   ('Katinka Barysch', 'PER'),
#   ('Kazimir', 'PER'),
#   ('Kees de Jager', 'PER'),
#   ('Kemal Ataturk', 'PER'),
#   ('Ken Sara-Wiwa', 'PER'),
#   ('Keulen', 'PER'),
#   ('Kinkel', 'PER'),
#   ('Kiro Gligorov', 'PER'),
#   ('Kissinger', 'PER'),
#   ('Klaas Broekhuizen', 'PER'),
#   ('Klaus', 'PER'),
#   ('Klaus Hansch', 'PER'),
#   ('Klaus Kinkel', 'PER'),
#   ('Klestil', 'PER'),
#   ('Knulst', 'PER'),
#   ('Kofi Annan', 'PER'),
#   ('Kohl', 'PER'),
#   ('Kohls', 'PER'),
#   ('Kok', 'PER'),
#   ('Koks', 'PER'),
#   ('Kolen', 'PER'),
#   ('Koninklijke', 'ORG'),
#   ('Koninklijke Marechaussee', 'ORG'),
#   ('Konrad', 'PER'),
#   ('Konrad Adenauer', 'PER'),
#   ('Kooijmans', 'PER'),
#   ('Korei', 'PER'),
#   ('Korfoe', 'PER'),
#   ('Koster', 'PER'),
#   ('Kostunica', 'PER'),
#   ('Kozyrev', 'PER'),
#   ('Krajisnik', 'PER'),
#   ('Kranten', 'ORG'),
#   ('Kreizberg', 'PER'),
#   ('Kuipers', 'PER'),
#   ('Kulturele Haadsted', 'ORG'),
#   ('Kupchan', 'PER'),
#   ('Kwasniewski', 'PER'),
#   ('L Espresso', 'PER'),
#   ('L.J.', 'PER'),
#   ('LAMBERT VAN NISTELROOIJ', 'PER'),
#   ('LENGTH', 'ORG'),
#   ('LPF', 'ORG'),
#   ('LUXEMBURG', 'ORG'),
#   ('La Repubblica', 'ORG'),
#   ('Labour', 'ORG'),
#   ('Labourregering', 'ORG'),
#   ('Lagerhuis', 'ORG'),
#   ('Lamassoure', 'PER'),
#   ('Lambert van Nistelrooij', 'PER'),
#   ('Lamberto Dini', 'PER'),
#   ('Lambsdorff', 'PER'),
#   ('Landbouwbeleid', 'ORG'),
#   ('Landbouwminister Van Aartsen', 'PER'),
#   ('Landelijk', 'ORG'),
#   ('Langenkamp', 'PER'),
#   ('Laurent-Desire Kabila', 'PER'),
#   ('Lavrov', 'PER'),
#   ('Leaf', 'PER'),
#   ('Lech Kaczynski', 'PER'),
#   ('Leefbaar', 'ORG'),
#   ('Leerling', 'PER'),
#   ('Lega Nord', 'ORG'),
#   ('Leon', 'PER'),
#   ('Leon Brittan', 'PER'),
#   ('Leon Cornelissen', 'PER'),
#   ('Leon Kamps', 'PER'),
#   ('Leonard Orban', 'PER'),
#   ('Leonard Orbanm', 'PER'),
#   ('Leonid Koetsjma', 'PER'),
#   ...],
#  'tool': VBox(children=(Label(value='Adami'), HBox(children=(Text(value='Adami', description='Root:', placeholder='Type something'), Button(description='Next', style=ButtonStyle()), Button(description='None', style=ButtonStyle()), Button(description='Previous', style=ButtonStyle())), layout=Layout(justify_content='space-between'))), layout=Layout(justify_content='space-around'))}
